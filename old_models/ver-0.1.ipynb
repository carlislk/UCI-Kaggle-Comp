# %%
# Iris Data

from sklearn.cross_validation import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.pipeline import Pipeline
from sklearn.svm import OneClassSVM
import sklearn.linear_model as lm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import xgboost as xgb

# Data Files

# kaggle.X1.names - primary feature names, in csv format
# kaggle.X1.train - primary feature values, training data set
# kaggle.X2.train - raw IR3 local image patches, training data set
# kaggle.Y.train - target values, training data set
# kaggle.X1.test - primary feature values, test data set
# kaggle.X2.test - raw IR3 local image patches, test data set

# Setup From 
# https://www.kaggle.com/yuansun/santander-customer-satisfaction/lb-0-84-for-starters/code

# from subprocess import check_output
# print(check_output(["ls", "../input"]).decode("utf8"))

# Any results you write to the current directory are saved as output.


# load data
df_train_1 = pd.read_csv('./data/kaggle.X1.train.txt', header=None)
df_train_2 = pd.read_csv('./data/kaggle.X2.train.txt', header=None)
df_train_Y = pd.read_csv('./data/kaggle.Y.train.txt', header=None)
df_test_1 = pd.read_csv('./data/kaggle.X1.test.txt', header=None)
df_test_2 = pd.read_csv('./data/kaggle.X1.test.txt', header=None)


# # remove constant columns
# remove = []
# for col in df_train.columns:
#     if df_train[col].std() == 0:
#         remove.append(col)

# df_train.drop(remove, axis=1, inplace=True)
# df_test.drop(remove, axis=1, inplace=True)

# # remove duplicated columns
# remove = []
# c = df_train.columns
# for i in range(len(c)-1):
#     v = df_train[c[i]].values
#     for j in range(i+1,len(c)):
#         if np.array_equal(v,df_train[c[j]].values):
#             remove.append(c[j])

# df_train.drop(remove, axis=1, inplace=True)
# df_test.drop(remove, axis=1, inplace=True)

# y_train = df_train['TARGET'].values
# X_train = df_train.drop(['ID','TARGET'], axis=1).values

# id_test = df_test['ID']
# X_test = df_test.drop(['ID'], axis=1).values

# # length of dataset
# len_train = len(X_train)
# len_test  = len(X_test)

# # classifier
# clf = xgb.XGBClassifier(missing=np.nan, max_depth=5, n_estimators=350, learning_rate=0.03, nthread=4, subsample=0.95, colsample_bytree=0.85, seed=4242)

# X_fit, X_eval, y_fit, y_eval= train_test_split(X_train, y_train, test_size=0.3)

# # fitting
# clf.fit(X_train, y_train, early_stopping_rounds=20, eval_metric="auc", eval_set=[(X_eval, y_eval)])

# print('Overall AUC:', roc_auc_score(y_train, clf.predict_proba(X_train)[:,1]))

# # predicting
# y_pred= clf.predict_proba(X_test)[:,1]

# submission = pd.DataFrame({"ID":id_test, "TARGET":y_pred})
# submission.to_csv("submission.csv", index=False)

# print('Completed!')

# %%
# # Combine Train Data 
# df_train_X = pd.concat([df_train_1, df_train_2], axis=1)

# # Combine Test Data 
# df_test_X = pd.concat([df_test_1, df_test_2], axis=1)


# Create Numpy Arrays
# X_train = df_train_X.values
y_train = df_train_Y.values
# X_test = df_test_X.values

X_train = df_train_1.values
X_test = df_test_1.values

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
# Out:
# (60000, 91)
# (60000, 1)
# (40000, 91)

# %%
# Train Models


# classifier XBG Regression
clf = xgb.XGBRegressor(missing=np.nan, max_depth=30, n_estimators=400, learning_rate=0.03, nthread=4, subsample=0.95, colsample_bytree=0.85, seed=4242 )

X_fit, X_eval, y_fit, y_eval= train_test_split(X_train, y_train, test_size=0.3)

# fitting
clf.fit(X_train, y_train, early_stopping_rounds=20, eval_metric="rmse", eval_set=[(X_eval, y_eval)])


# predicting
#y_pred= clf.predict_proba(X_test)[:,1]
y_pred= clf.predict(X_test)



print('Completed!')
# Both Feature Sets
# [349]	validation_0-rmse:0.544184
# [160]	validation_0-rmse:0.536579

# Single Feature Set
# [160]	validation_0-rmse:0.561419

# 9th place  max_depth=20, n_estimators=161, learning_rate=0.03, nthread=4, subsample=0.95, colsample_bytree=0.85, seed=4242 )
#[160]	validation_0-rmse:0.118262
# Out:
# Will train until validation_0 error hasn't decreased in 20 rounds.
# [0]	validation_0-rmse:0.817995
# [1]	validation_0-rmse:0.798358
# [2]	validation_0-rmse:0.779147
# [3]	validation_0-rmse:0.760452
# [4]	validation_0-rmse:0.742369
# [5]	validation_0-rmse:0.724476
# [6]	validation_0-rmse:0.707203
# [7]	validation_0-rmse:0.690369
# [8]	validation_0-rmse:0.673774
# [9]	validation_0-rmse:0.657762
# [10]	validation_0-rmse:0.642336
# [11]	validation_0-rmse:0.627300
# [12]	validation_0-rmse:0.612628
# [13]	validation_0-rmse:0.598306
# [14]	validation_0-rmse:0.584364
# [15]	validation_0-rmse:0.570755
# [16]	validation_0-rmse:0.557561
# [17]	validation_0-rmse:0.544753
# [18]	validation_0-rmse:0.532287
# [19]	validation_0-rmse:0.520061
# [20]	validation_0-rmse:0.508175
# [21]	validation_0-rmse:0.496609
# [22]	validation_0-rmse:0.485451
# [23]	validation_0-rmse:0.474551
# [24]	validation_0-rmse:0.463800
# [25]	validation_0-rmse:0.453179
# [26]	validation_0-rmse:0.443121
# [27]	validation_0-rmse:0.433374
# [28]	validation_0-rmse:0.423708
# [29]	validation_0-rmse:0.414421
# [30]	validation_0-rmse:0.405380
# [31]	validation_0-rmse:0.396596
# [32]	validation_0-rmse:0.387976
# [33]	validation_0-rmse:0.379584
# [34]	validation_0-rmse:0.371410
# [35]	validation_0-rmse:0.363598
# [36]	validation_0-rmse:0.355858
# [37]	validation_0-rmse:0.348393
# [38]	validation_0-rmse:0.341022
# [39]	validation_0-rmse:0.333887
# [40]	validation_0-rmse:0.326937
# [41]	validation_0-rmse:0.320158
# [42]	validation_0-rmse:0.313663
# [43]	validation_0-rmse:0.307147
# [44]	validation_0-rmse:0.300939
# [45]	validation_0-rmse:0.294872
# [46]	validation_0-rmse:0.288886
# [47]	validation_0-rmse:0.283112
# [48]	validation_0-rmse:0.277550
# [49]	validation_0-rmse:0.272156
# [50]	validation_0-rmse:0.266703
# [51]	validation_0-rmse:0.261549
# [52]	validation_0-rmse:0.256620
# [53]	validation_0-rmse:0.251797
# [54]	validation_0-rmse:0.247165
# [55]	validation_0-rmse:0.242763
# [56]	validation_0-rmse:0.238274
# [57]	validation_0-rmse:0.233999
# [58]	validation_0-rmse:0.229769
# [59]	validation_0-rmse:0.225760
# [60]	validation_0-rmse:0.221788
# [61]	validation_0-rmse:0.218006
# [62]	validation_0-rmse:0.214339
# [63]	validation_0-rmse:0.210712
# [64]	validation_0-rmse:0.207140
# [65]	validation_0-rmse:0.203766
# [66]	validation_0-rmse:0.200528
# [67]	validation_0-rmse:0.197339
# [68]	validation_0-rmse:0.194124
# [69]	validation_0-rmse:0.191154
# [70]	validation_0-rmse:0.188134
# [71]	validation_0-rmse:0.185234
# [72]	validation_0-rmse:0.182495
# [73]	validation_0-rmse:0.179861
# [74]	validation_0-rmse:0.177254
# [75]	validation_0-rmse:0.174748
# [76]	validation_0-rmse:0.172292
# [77]	validation_0-rmse:0.169972
# [166]	validation_0-rmse:0.108345
# [167]	validation_0-rmse:0.108238
# [168]	validation_0-rmse:0.108174
# [169]	validation_0-rmse:0.108141
# [170]	validation_0-rmse:0.108087
# [171]	validation_0-rmse:0.108024
# [172]	validation_0-rmse:0.107978
# [173]	validation_0-rmse:0.107960
# [174]	validation_0-rmse:0.107912
# [175]	validation_0-rmse:0.107882
# [176]	validation_0-rmse:0.107833
# [177]	validation_0-rmse:0.107809
# [178]	validation_0-rmse:0.107753
# [179]	validation_0-rmse:0.107707
# [180]	validation_0-rmse:0.107674
# [181]	validation_0-rmse:0.107644
# [182]	validation_0-rmse:0.107606
# [183]	validation_0-rmse:0.107593
# [184]	validation_0-rmse:0.107560
# [185]	validation_0-rmse:0.107536
# [186]	validation_0-rmse:0.107486
# [187]	validation_0-rmse:0.107450
# [188]	validation_0-rmse:0.107423
# [189]	validation_0-rmse:0.107402
# [190]	validation_0-rmse:0.107393
# [191]	validation_0-rmse:0.107396
# [192]	validation_0-rmse:0.107410
# [193]	validation_0-rmse:0.107412
# [194]	validation_0-rmse:0.107399
# [195]	validation_0-rmse:0.107380
# [196]	validation_0-rmse:0.107398
# [197]	validation_0-rmse:0.107381
# [198]	validation_0-rmse:0.107369
# [199]	validation_0-rmse:0.107366
# [200]	validation_0-rmse:0.107357
# [201]	validation_0-rmse:0.107371
# [202]	validation_0-rmse:0.107369
# [203]	validation_0-rmse:0.107336
# [204]	validation_0-rmse:0.107319
# [205]	validation_0-rmse:0.107309
# [206]	validation_0-rmse:0.107292
# [207]	validation_0-rmse:0.107293
# [208]	validation_0-rmse:0.107290
# [209]	validation_0-rmse:0.107286
# [210]	validation_0-rmse:0.107287
# [211]	validation_0-rmse:0.107282
# [212]	validation_0-rmse:0.107277
# [213]	validation_0-rmse:0.107295
# [214]	validation_0-rmse:0.107283
# [215]	validation_0-rmse:0.107278
# [216]	validation_0-rmse:0.107269
# [217]	validation_0-rmse:0.107244
# [218]	validation_0-rmse:0.107247
# [219]	validation_0-rmse:0.107242
# [220]	validation_0-rmse:0.107246
# [221]	validation_0-rmse:0.107234
# [222]	validation_0-rmse:0.107227
# [223]	validation_0-rmse:0.107212
# [224]	validation_0-rmse:0.107210
# [225]	validation_0-rmse:0.107212
# [226]	validation_0-rmse:0.107230
# [227]	validation_0-rmse:0.107218
# [228]	validation_0-rmse:0.107244
# [229]	validation_0-rmse:0.107241
# [230]	validation_0-rmse:0.107235
# [231]	validation_0-rmse:0.107229
# [232]	validation_0-rmse:0.107230
# [233]	validation_0-rmse:0.107229
# [234]	validation_0-rmse:0.107234
# [235]	validation_0-rmse:0.107233
# [236]	validation_0-rmse:0.107237
# [237]	validation_0-rmse:0.107232
# [238]	validation_0-rmse:0.107236
# [239]	validation_0-rmse:0.107229
# [240]	validation_0-rmse:0.107223
# [241]	validation_0-rmse:0.107218
# [242]	validation_0-rmse:0.107227
# [243]	validation_0-rmse:0.107237
# [244]	validation_0-rmse:0.107239
# Completed!
# Stopping. Best iteration:
# [224]	validation_0-rmse:0.107210

# %%
import csv

write_file = open('predictions_1.csv', 'w')
write_file.write('ID,Prediction\n')
for x,y in enumerate(y_pred):
    write_file.write('{},{} \n'.format(x+1, y))
                     
write_file.close()

print(y_pred.shape)
print('Completed!')
# Out:
# (40000,)
# Completed!
