# %%
# Results

# Both Feature Sets
# [349]	validation_0-rmse:0.544184
# [160]	validation_0-rmse:0.536579

# Single Feature Set
# [160]	validation_0-rmse:0.561419

# 9th place  max_depth=20, n_estimators=161, learning_rate=0.03, nthread=4, subsample=0.95, colsample_bytree=0.85, seed=4242 )
#[160]	validation_0-rmse:0.118262

# %%
# Iris Data

from sklearn.cross_validation import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.pipeline import Pipeline
from sklearn.svm import OneClassSVM
import sklearn.linear_model as lm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import xgboost as xgb

# Data Files

# load data
df_train_1 = pd.read_csv('./data/kaggle.X1.train.txt', header=None)
df_train_2 = pd.read_csv('./data/kaggle.X2.train.txt', header=None)
df_train_Y = pd.read_csv('./data/kaggle.Y.train.txt', header=None)
df_test_1 = pd.read_csv('./data/kaggle.X1.test.txt', header=None)
df_test_2 = pd.read_csv('./data/kaggle.X2.test.txt', header=None)

# Combine Train Data 
df_train_X = pd.concat([df_train_1, df_train_2], axis=1)

# Combine Test Data 
df_test_X = pd.concat([df_test_1, df_test_2], axis=1)


# Create Numpy Arrays
X_train = df_train_X.values
y_train = df_train_Y.values
X_test = df_test_X.values

# Use Only X1
# X_train = df_train_1.values
# X_test = df_test_1.values

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
# Out:
# (60000, 532)
# (60000, 1)
# (40000, 532)

# %%
# Train Model

depth = 10
estimator = 900
l_rate = 0.03
sub_sample = 0.94
col_sample = 0.85
seed_val = 4242
# n_round = 2
# verbose_val = 2
alpha_val = 0.7
#lambda_val = 1.0

# classifier XBG Regression
clf = xgb.XGBRegressor(missing=np.nan, max_depth=depth, n_estimators=estimator, 
                       learning_rate=l_rate, nthread=4, subsample=sub_sample, colsample_bytree=col_sample, 
                       seed=seed_val, reg_alpha = alpha_val)

X_fit, X_eval, y_fit, y_eval= train_test_split(X_train, y_train, test_size=0.2)

# fitting
# !! I Changed the fit paremeters to (X_fit, y_fit, )
clf.fit(X_fit, y_fit, early_stopping_rounds=20, eval_metric="rmse", eval_set=[(X_eval, y_eval)])

# predicting
y_pred= clf.predict(X_test)

print("Done!")
# Out:
# Will train until validation_0 error hasn't decreased in 20 rounds.
# [0]	validation_0-rmse:0.835585
# [1]	validation_0-rmse:0.825361
# [2]	validation_0-rmse:0.815440
# [3]	validation_0-rmse:0.806162
# [4]	validation_0-rmse:0.796855
# [5]	validation_0-rmse:0.788514
# [6]	validation_0-rmse:0.780405
# [7]	validation_0-rmse:0.772467
# [8]	validation_0-rmse:0.764562
# [9]	validation_0-rmse:0.757196
# [10]	validation_0-rmse:0.750455
# [11]	validation_0-rmse:0.743647
# [12]	validation_0-rmse:0.737423
# [13]	validation_0-rmse:0.731717
# [14]	validation_0-rmse:0.725854
# [15]	validation_0-rmse:0.720357
# [16]	validation_0-rmse:0.715008
# [17]	validation_0-rmse:0.709799
# [18]	validation_0-rmse:0.704856
# [19]	validation_0-rmse:0.700246
# [20]	validation_0-rmse:0.696046
# [21]	validation_0-rmse:0.691513
# [22]	validation_0-rmse:0.687768
# [23]	validation_0-rmse:0.683844
# [24]	validation_0-rmse:0.680107
# [25]	validation_0-rmse:0.676563
# [26]	validation_0-rmse:0.673259
# [27]	validation_0-rmse:0.669944
# [28]	validation_0-rmse:0.666937
# [29]	validation_0-rmse:0.663850
# [30]	validation_0-rmse:0.660928
# [31]	validation_0-rmse:0.658239
# [121]	validation_0-rmse:0.593614
# [122]	validation_0-rmse:0.593449
# [123]	validation_0-rmse:0.593257
# [124]	validation_0-rmse:0.593122
# [125]	validation_0-rmse:0.592863
# [126]	validation_0-rmse:0.592831
# [127]	validation_0-rmse:0.592695
# [128]	validation_0-rmse:0.592497
# [129]	validation_0-rmse:0.592351
# [130]	validation_0-rmse:0.592229
# [131]	validation_0-rmse:0.592103
# [132]	validation_0-rmse:0.591902
# [133]	validation_0-rmse:0.591814
# [134]	validation_0-rmse:0.591662
# [135]	validation_0-rmse:0.591558
# [136]	validation_0-rmse:0.591414
# [137]	validation_0-rmse:0.591360
# [138]	validation_0-rmse:0.591266
# [139]	validation_0-rmse:0.591214
# [140]	validation_0-rmse:0.591148
# [141]	validation_0-rmse:0.591036
# [142]	validation_0-rmse:0.590942
# [143]	validation_0-rmse:0.590930
# [144]	validation_0-rmse:0.590903
# [145]	validation_0-rmse:0.590869
# [146]	validation_0-rmse:0.590836
# [147]	validation_0-rmse:0.590757
# [148]	validation_0-rmse:0.590657
# [149]	validation_0-rmse:0.590563
# [150]	validation_0-rmse:0.590517
# [151]	validation_0-rmse:0.590461
# [152]	validation_0-rmse:0.590388
# [153]	validation_0-rmse:0.590335
# [154]	validation_0-rmse:0.590232
# [155]	validation_0-rmse:0.590118
# [156]	validation_0-rmse:0.590067
# [157]	validation_0-rmse:0.590008
# [158]	validation_0-rmse:0.589800
# [159]	validation_0-rmse:0.589754
# [160]	validation_0-rmse:0.589757
# [161]	validation_0-rmse:0.589717
# [162]	validation_0-rmse:0.589647
# [163]	validation_0-rmse:0.589535
# [164]	validation_0-rmse:0.589534
# [165]	validation_0-rmse:0.589435
# [166]	validation_0-rmse:0.589371
# [167]	validation_0-rmse:0.589294
# [168]	validation_0-rmse:0.589316
# [169]	validation_0-rmse:0.589260
# [170]	validation_0-rmse:0.589179
# [171]	validation_0-rmse:0.589086
# [172]	validation_0-rmse:0.589034
# [173]	validation_0-rmse:0.588949
# [174]	validation_0-rmse:0.588921
# [175]	validation_0-rmse:0.588900
# [176]	validation_0-rmse:0.588875
# [177]	validation_0-rmse:0.588849
# [178]	validation_0-rmse:0.588836
# [179]	validation_0-rmse:0.588784
# [180]	validation_0-rmse:0.588699
# [181]	validation_0-rmse:0.588646
# [182]	validation_0-rmse:0.588614
# [183]	validation_0-rmse:0.588499
# [184]	validation_0-rmse:0.588442
# [185]	validation_0-rmse:0.588358
# [186]	validation_0-rmse:0.588264
# [187]	validation_0-rmse:0.588191
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-589f1e51591a> in <module>()
#      21 # fitting
#      22 # !! I Changed the fit paremeters to (X_fit, y_fit, )
# ---> 23 clf.fit(X_fit, y_fit, early_stopping_rounds=20, eval_metric="rmse", eval_set=[(X_eval, y_eval)])
#      24
#      25 # predicting
#
# /home/carlislk/anaconda3/lib/python3.5/site-packages/xgboost/sklearn.py in fit(self, X, y, eval_set, eval_metric, early_stopping_rounds, verbose)
#     186                               early_stopping_rounds=early_stopping_rounds,
#     187                               evals_result=evals_result, feval=feval,
# --> 188                               verbose_eval=verbose)
#     189
#     190         if evals_result:
#
# /home/carlislk/anaconda3/lib/python3.5/site-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, learning_rates, xgb_model)
#     196                 else:
#     197                     bst.set_param({'eta': learning_rates(i, num_boost_round)})
# --> 198             bst.update(dtrain, i, obj)
#     199             nboost += 1
#     200             bst_eval_set = bst.eval_set(evals, i, feval)
#
# /home/carlislk/anaconda3/lib/python3.5/site-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#     692
#     693         if fobj is None:
# --> 694             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, iteration, dtrain.handle))
#     695         else:
#     696             pred = self.predict(dtrain)
#
# KeyboardInterrupt:

# %%
# Score

from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import median_absolute_error
from sklearn.metrics import r2_score

# Print Parameters
print("Parameters")
print()
print("Depth: ", depth)
print("estimator: ", estimator)
print("l_rate: ", l_rate)
print("sub_sample: ", sub_sample)
print("col_sample: ", col_sample)
print("seed: ", seed_val)
print("Alpha: ", alpha_val)
#print("Lambda: ", lambda_val)
# print("Num Rounds: ", n_round)
# print("Verbose Val: ", verbose_val)
print()
print()


# Score On Full Train Set
full_train_pred = clf.predict(X_train)
print(" -- Scores -- Full Train -- ")
print("Explained Variance Score: ", explained_variance_score(y_train, full_train_pred ))
print("Mean Absolute Error: ", mean_absolute_error(y_train, full_train_pred))
print("Mean Squared Error: ", mean_squared_error(y_train, full_train_pred))
print("Median Absolute Error: ", median_absolute_error(y_train, full_train_pred))
print("R2 Score: ", r2_score(y_train, full_train_pred))
print()
print()

# Score On Train Split
split_train_pred = clf.predict(X_fit)
print(" -- Scores -- Train Split -- ")
print("Explained Variance Score: ", explained_variance_score(y_fit, split_train_pred ))
print("Mean Absolute Error: ", mean_absolute_error(y_fit, split_train_pred))
print("Mean Squared Error: ", mean_squared_error(y_fit, split_train_pred))
print("Median Absolute Error: ", median_absolute_error(y_fit, split_train_pred))
print("R2 Score: ", r2_score(y_fit, split_train_pred))
print()
print()

# Score On Test Split
split_test_pred = clf.predict(X_eval)
print(" -- Scores -- Test Split -- ")
print("Explained Variance Score: ", explained_variance_score(y_eval, split_test_pred ))
print("Mean Absolute Error: ", mean_absolute_error(y_eval, split_test_pred))
print("Mean Squared Error: ", mean_squared_error(y_eval, split_test_pred))
print("Median Absolute Error: ", median_absolute_error(y_eval, split_test_pred))
print("R2 Score: ", r2_score(y_eval, split_test_pred))
print()
# Out:
# Parameters
#
# Depth:  10
# estimator:  500
# l_rate:  0.03
# sub_sample:  0.94
# col_sample:  0.85
# seed:  4242
# Alpha:  0.7
#
#
#  -- Scores -- Full Train --
# Explained Variance Score:  0.878104869704
# Mean Absolute Error:  0.155315880464
# Mean Squared Error:  0.0848788991495
# Median Absolute Error:  0.0776768228693
# R2 Score:  0.878104761327
#
#
#  -- Scores -- Train Split --
# Explained Variance Score:  0.963365822253
# Mean Absolute Error:  0.105476792881
# Mean Squared Error:  0.0256037943083
# Median Absolute Error:  0.0661874556177
# R2 Score:  0.963365477479
#
#
#  -- Scores -- Test Split --
# Explained Variance Score:  0.530666214944
# Mean Absolute Error:  0.354672230798
# Mean Squared Error:  0.321979318514
# Median Absolute Error:  0.198201310777
# R2 Score:  0.530665707603

# %%
# Score on Test File From 9th Place Prediction

# %%
# Write To File
import csv

write_file = open('predictions_1.csv', 'w')
write_file.write('ID,Prediction\n')
for x,y in enumerate(y_pred):
    write_file.write('{},{} \n'.format(x+1, y))
    
                     
write_file.close()

print(y_pred.shape)

print('Completed!')
# Out:
# (40000,)
# Completed!
