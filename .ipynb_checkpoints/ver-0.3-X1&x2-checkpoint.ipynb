# %%
# Results

# Both Feature Sets
# [349]	validation_0-rmse:0.544184
# [160]	validation_0-rmse:0.536579

# Single Feature Set
# [160]	validation_0-rmse:0.561419

# 9th place  max_depth=20, n_estimators=161, learning_rate=0.03, nthread=4, subsample=0.95, colsample_bytree=0.85, seed=4242 )
#[160]	validation_0-rmse:0.118262

# %%
# Iris Data

from sklearn.cross_validation import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.pipeline import Pipeline
from sklearn.svm import OneClassSVM
import sklearn.linear_model as lm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import xgboost as xgb

# Data Files

# load data
df_train_1 = pd.read_csv('./data/kaggle.X1.train.txt', header=None)
df_train_2 = pd.read_csv('./data/kaggle.X2.train.txt', header=None)
df_train_Y = pd.read_csv('./data/kaggle.Y.train.txt', header=None)
df_test_1 = pd.read_csv('./data/kaggle.X1.test.txt', header=None)
df_test_2 = pd.read_csv('./data/kaggle.X2.test.txt', header=None)

# # Combine Train Data 
# df_train_X = pd.concat([df_train_1, df_train_2], axis=1)

# # Combine Test Data 
# df_test_X = pd.concat([df_test_1, df_test_2], axis=1)


# Create Numpy Arrays
# X_train = df_train_X.values
y_train = df_train_Y.values
# X_test = df_test_X.values

# Use Only X1
X_train = df_train_1.values
X_test = df_test_1.values

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
# Out:
# (60000, 91)
# (60000, 1)
# (40000, 91)

# %%
# Train Model

depth = 10
estimator = 500
l_rate = 0.03
sub_sample = 0.94
col_sample = 0.85
seed_val = 4242
# n_round = 2
# verbose_val = 2
alpha_val = 0.7
#lambda_val = 1.0

# classifier XBG Regression
clf = xgb.XGBRegressor(missing=np.nan, max_depth=depth, n_estimators=estimator, 
                       learning_rate=l_rate, nthread=4, subsample=sub_sample, colsample_bytree=col_sample, 
                       seed=seed_val, reg_alpha = alpha_val)

X_fit, X_eval, y_fit, y_eval= train_test_split(X_train, y_train, test_size=0.2)

# fitting
# !! I Changed the fit paremeters to (X_fit, y_fit, )
clf.fit(X_fit, y_fit, early_stopping_rounds=20, eval_metric="rmse", eval_set=[(X_eval, y_eval)])

# predicting
y_pred= clf.predict(X_test)

print("Done!")
# Out:
# Will train until validation_0 error hasn't decreased in 20 rounds.
# [0]	validation_0-rmse:0.830511
# [1]	validation_0-rmse:0.819845
# [2]	validation_0-rmse:0.809877
# [3]	validation_0-rmse:0.800276
# [4]	validation_0-rmse:0.791245
# [5]	validation_0-rmse:0.783051
# [6]	validation_0-rmse:0.774691
# [7]	validation_0-rmse:0.766956
# [8]	validation_0-rmse:0.759240
# [9]	validation_0-rmse:0.751785
# [10]	validation_0-rmse:0.745155
# [11]	validation_0-rmse:0.738669
# [12]	validation_0-rmse:0.732192
# [13]	validation_0-rmse:0.726175
# [14]	validation_0-rmse:0.720510
# [15]	validation_0-rmse:0.714761
# [16]	validation_0-rmse:0.709487
# [17]	validation_0-rmse:0.704182
# [18]	validation_0-rmse:0.699238
# [19]	validation_0-rmse:0.694586
# [20]	validation_0-rmse:0.690162
# [21]	validation_0-rmse:0.685929
# [22]	validation_0-rmse:0.682182
# [23]	validation_0-rmse:0.678277
# [24]	validation_0-rmse:0.674608
# [25]	validation_0-rmse:0.671209
# [26]	validation_0-rmse:0.667953
# [27]	validation_0-rmse:0.664862
# [28]	validation_0-rmse:0.661645
# [29]	validation_0-rmse:0.658695
# [30]	validation_0-rmse:0.655900
# [31]	validation_0-rmse:0.653153
# [32]	validation_0-rmse:0.650375
# [33]	validation_0-rmse:0.647990
# [34]	validation_0-rmse:0.645735
# [35]	validation_0-rmse:0.643497
# [36]	validation_0-rmse:0.641339
# [37]	validation_0-rmse:0.639457
# [38]	validation_0-rmse:0.637566
# [39]	validation_0-rmse:0.635662
# [40]	validation_0-rmse:0.633643
# [41]	validation_0-rmse:0.631777
# [42]	validation_0-rmse:0.630202
# [43]	validation_0-rmse:0.628510
# [44]	validation_0-rmse:0.627149
# [45]	validation_0-rmse:0.625793
# [46]	validation_0-rmse:0.624436
# [47]	validation_0-rmse:0.623293
# [48]	validation_0-rmse:0.622016
# [49]	validation_0-rmse:0.620776
# [50]	validation_0-rmse:0.619563
# [51]	validation_0-rmse:0.618533
# [52]	validation_0-rmse:0.617528
# [53]	validation_0-rmse:0.616571
# [54]	validation_0-rmse:0.615754
# [55]	validation_0-rmse:0.614763
# [56]	validation_0-rmse:0.613755
# [57]	validation_0-rmse:0.612761
# [58]	validation_0-rmse:0.612134
# [59]	validation_0-rmse:0.611417
# [60]	validation_0-rmse:0.610659
# [61]	validation_0-rmse:0.609819
# [62]	validation_0-rmse:0.609093
# [63]	validation_0-rmse:0.608552
# [64]	validation_0-rmse:0.607921
# [65]	validation_0-rmse:0.607340
# [66]	validation_0-rmse:0.606966
# [67]	validation_0-rmse:0.606408
# [68]	validation_0-rmse:0.605874
# [69]	validation_0-rmse:0.605450
# [70]	validation_0-rmse:0.604939
# [71]	validation_0-rmse:0.604492
# [72]	validation_0-rmse:0.604091
# [73]	validation_0-rmse:0.603687
# [74]	validation_0-rmse:0.603205
# [75]	validation_0-rmse:0.602887
# [76]	validation_0-rmse:0.602511
# [77]	validation_0-rmse:0.602134
# [78]	validation_0-rmse:0.601837
# [79]	validation_0-rmse:0.601497
# [80]	validation_0-rmse:0.601247
# [81]	validation_0-rmse:0.600915
# [82]	validation_0-rmse:0.600628
# [83]	validation_0-rmse:0.600441
# [84]	validation_0-rmse:0.600197
# [85]	validation_0-rmse:0.599946
# [86]	validation_0-rmse:0.599668
# [87]	validation_0-rmse:0.599304
# [88]	validation_0-rmse:0.599166
# [89]	validation_0-rmse:0.598852
# [90]	validation_0-rmse:0.598563
# [91]	validation_0-rmse:0.598326
# [92]	validation_0-rmse:0.598012
# [93]	validation_0-rmse:0.597868
# [94]	validation_0-rmse:0.597639
# [95]	validation_0-rmse:0.597389
# [96]	validation_0-rmse:0.597238
# [97]	validation_0-rmse:0.597127
# [98]	validation_0-rmse:0.596929
# [99]	validation_0-rmse:0.596728
# [100]	validation_0-rmse:0.596369
# [101]	validation_0-rmse:0.596329
# [102]	validation_0-rmse:0.596095
# [103]	validation_0-rmse:0.595976
# [104]	validation_0-rmse:0.595706
# [105]	validation_0-rmse:0.595533
# [106]	validation_0-rmse:0.595478
# [107]	validation_0-rmse:0.595241
# [108]	validation_0-rmse:0.595128
# [109]	validation_0-rmse:0.595028
# [110]	validation_0-rmse:0.594879
# [111]	validation_0-rmse:0.594713
# [112]	validation_0-rmse:0.594530
# [113]	validation_0-rmse:0.594316
# [114]	validation_0-rmse:0.594154
# [115]	validation_0-rmse:0.594057
# [116]	validation_0-rmse:0.593951
# [117]	validation_0-rmse:0.593768
# [118]	validation_0-rmse:0.593576
# [119]	validation_0-rmse:0.593472
# [120]	validation_0-rmse:0.593401
# [121]	validation_0-rmse:0.593351
# [122]	validation_0-rmse:0.593215
# [123]	validation_0-rmse:0.593089
# [124]	validation_0-rmse:0.592962
# [125]	validation_0-rmse:0.592891
# [126]	validation_0-rmse:0.592783
# [127]	validation_0-rmse:0.592738
# [128]	validation_0-rmse:0.592631
# [129]	validation_0-rmse:0.592514
# [130]	validation_0-rmse:0.592356
# [131]	validation_0-rmse:0.592328
# [132]	validation_0-rmse:0.592160
# [133]	validation_0-rmse:0.591968
# [134]	validation_0-rmse:0.591829
# [135]	validation_0-rmse:0.591724
# [136]	validation_0-rmse:0.591592
# [137]	validation_0-rmse:0.591516
# [138]	validation_0-rmse:0.591472
# [139]	validation_0-rmse:0.591327
# [140]	validation_0-rmse:0.591305
# [141]	validation_0-rmse:0.591221
# [142]	validation_0-rmse:0.591135
# [143]	validation_0-rmse:0.590977
# [144]	validation_0-rmse:0.590957
# [145]	validation_0-rmse:0.590925
# [146]	validation_0-rmse:0.590859
# [147]	validation_0-rmse:0.590813
# [148]	validation_0-rmse:0.590805
# [149]	validation_0-rmse:0.590733
# [150]	validation_0-rmse:0.590674
# [151]	validation_0-rmse:0.590492
# [152]	validation_0-rmse:0.590437
# [153]	validation_0-rmse:0.590374
# [154]	validation_0-rmse:0.590317
# [155]	validation_0-rmse:0.590239
# [156]	validation_0-rmse:0.590236
# [157]	validation_0-rmse:0.590245
# [158]	validation_0-rmse:0.590150
# [159]	validation_0-rmse:0.590148
# [160]	validation_0-rmse:0.590057
# [161]	validation_0-rmse:0.590020
# [162]	validation_0-rmse:0.589934
# [163]	validation_0-rmse:0.589860
# [164]	validation_0-rmse:0.589841
# [165]	validation_0-rmse:0.589768
# [166]	validation_0-rmse:0.589738
# [167]	validation_0-rmse:0.589731
# [168]	validation_0-rmse:0.589623
# [169]	validation_0-rmse:0.589559
# [170]	validation_0-rmse:0.589581
# [171]	validation_0-rmse:0.589553
# [172]	validation_0-rmse:0.589484
# [173]	validation_0-rmse:0.589425
# [174]	validation_0-rmse:0.589440
# [175]	validation_0-rmse:0.589356
# [176]	validation_0-rmse:0.589292
# [177]	validation_0-rmse:0.589282
# [178]	validation_0-rmse:0.589212
# [179]	validation_0-rmse:0.589150
# [180]	validation_0-rmse:0.589163
# [181]	validation_0-rmse:0.589134
# [182]	validation_0-rmse:0.589071
# [183]	validation_0-rmse:0.588987
# [184]	validation_0-rmse:0.588912
# [185]	validation_0-rmse:0.588922
# [186]	validation_0-rmse:0.588939
# [187]	validation_0-rmse:0.588933
# [188]	validation_0-rmse:0.588999
# [189]	validation_0-rmse:0.588991
# [190]	validation_0-rmse:0.588915
# [191]	validation_0-rmse:0.588926
# [192]	validation_0-rmse:0.588916
# [193]	validation_0-rmse:0.588892
# [194]	validation_0-rmse:0.588903
# [195]	validation_0-rmse:0.588838
# [196]	validation_0-rmse:0.588842
# [197]	validation_0-rmse:0.588883
# [198]	validation_0-rmse:0.588837
# [199]	validation_0-rmse:0.588824
# [200]	validation_0-rmse:0.588800
# [201]	validation_0-rmse:0.588762
# [202]	validation_0-rmse:0.588714
# [203]	validation_0-rmse:0.588668
# [204]	validation_0-rmse:0.588636
# [205]	validation_0-rmse:0.588608
# [206]	validation_0-rmse:0.588522
# [207]	validation_0-rmse:0.588514
# [208]	validation_0-rmse:0.588481
# [209]	validation_0-rmse:0.588489
# [210]	validation_0-rmse:0.588416
# [211]	validation_0-rmse:0.588373
# [212]	validation_0-rmse:0.588343
# [213]	validation_0-rmse:0.588291
# [214]	validation_0-rmse:0.588276
# [215]	validation_0-rmse:0.588230
# [216]	validation_0-rmse:0.588226
# [217]	validation_0-rmse:0.588204
# [218]	validation_0-rmse:0.588192
# [219]	validation_0-rmse:0.588108
# [220]	validation_0-rmse:0.588117
# [221]	validation_0-rmse:0.588075
# [222]	validation_0-rmse:0.588007
# [223]	validation_0-rmse:0.587969
# [224]	validation_0-rmse:0.587986
# [225]	validation_0-rmse:0.587928
# [226]	validation_0-rmse:0.587865
# [227]	validation_0-rmse:0.587840
# [228]	validation_0-rmse:0.587839
# [229]	validation_0-rmse:0.587819
# [230]	validation_0-rmse:0.587830
# [231]	validation_0-rmse:0.587804
# [232]	validation_0-rmse:0.587839
# [233]	validation_0-rmse:0.587796
# [234]	validation_0-rmse:0.587753
# [235]	validation_0-rmse:0.587732
# [236]	validation_0-rmse:0.587706
# [237]	validation_0-rmse:0.587725
# [238]	validation_0-rmse:0.587695
# [239]	validation_0-rmse:0.587657
# [240]	validation_0-rmse:0.587602
# [241]	validation_0-rmse:0.587530
# [242]	validation_0-rmse:0.587530
# [243]	validation_0-rmse:0.587514
# [244]	validation_0-rmse:0.587524
# [245]	validation_0-rmse:0.587490
# [246]	validation_0-rmse:0.587459
# [247]	validation_0-rmse:0.587450
# [248]	validation_0-rmse:0.587444
# [249]	validation_0-rmse:0.587457
# [250]	validation_0-rmse:0.587428
# [251]	validation_0-rmse:0.587385
# [252]	validation_0-rmse:0.587349
# [253]	validation_0-rmse:0.587252
# [254]	validation_0-rmse:0.587241
# [255]	validation_0-rmse:0.587243
# [256]	validation_0-rmse:0.587240
# [257]	validation_0-rmse:0.587216
# [258]	validation_0-rmse:0.587213
# [259]	validation_0-rmse:0.587191
# [260]	validation_0-rmse:0.587164
# [261]	validation_0-rmse:0.587162
# [262]	validation_0-rmse:0.587127
# [263]	validation_0-rmse:0.587070
# [264]	validation_0-rmse:0.586984
# [265]	validation_0-rmse:0.586969
# [266]	validation_0-rmse:0.586912
# [267]	validation_0-rmse:0.586888
# [268]	validation_0-rmse:0.586844
# [269]	validation_0-rmse:0.586834
# [270]	validation_0-rmse:0.586803
# [271]	validation_0-rmse:0.586803
# [272]	validation_0-rmse:0.586778
# [273]	validation_0-rmse:0.586768
# [274]	validation_0-rmse:0.586778
# [275]	validation_0-rmse:0.586760
# [276]	validation_0-rmse:0.586774
# [277]	validation_0-rmse:0.586786
# [278]	validation_0-rmse:0.586783
# [279]	validation_0-rmse:0.586809
# [280]	validation_0-rmse:0.586805
# [281]	validation_0-rmse:0.586822
# [282]	validation_0-rmse:0.586834
# [283]	validation_0-rmse:0.586817
# [284]	validation_0-rmse:0.586806
# [285]	validation_0-rmse:0.586766
# [286]	validation_0-rmse:0.586787
# [287]	validation_0-rmse:0.586806
# [288]	validation_0-rmse:0.586827
# [289]	validation_0-rmse:0.586791
# [290]	validation_0-rmse:0.586762
# [291]	validation_0-rmse:0.586743
# [292]	validation_0-rmse:0.586757
# [293]	validation_0-rmse:0.586790
# [294]	validation_0-rmse:0.586793
# [295]	validation_0-rmse:0.586742
# [296]	validation_0-rmse:0.586664
# [297]	validation_0-rmse:0.586644
# [298]	validation_0-rmse:0.586632
# [299]	validation_0-rmse:0.586650
# [300]	validation_0-rmse:0.586652
# [301]	validation_0-rmse:0.586643
# [302]	validation_0-rmse:0.586654
# [303]	validation_0-rmse:0.586620
# [304]	validation_0-rmse:0.586621
# [305]	validation_0-rmse:0.586614
# [306]	validation_0-rmse:0.586616
# [307]	validation_0-rmse:0.586611
# [308]	validation_0-rmse:0.586619
# [309]	validation_0-rmse:0.586630
# [310]	validation_0-rmse:0.586622
# [311]	validation_0-rmse:0.586610
# [312]	validation_0-rmse:0.586629
# [313]	validation_0-rmse:0.586585
# [314]	validation_0-rmse:0.586584
# [315]	validation_0-rmse:0.586539
# [316]	validation_0-rmse:0.586554
# [317]	validation_0-rmse:0.586567
# [318]	validation_0-rmse:0.586507
# [319]	validation_0-rmse:0.586505
# [320]	validation_0-rmse:0.586520
# [321]	validation_0-rmse:0.586500
# [322]	validation_0-rmse:0.586504
# [323]	validation_0-rmse:0.586503
# [324]	validation_0-rmse:0.586509
# [325]	validation_0-rmse:0.586521
# [326]	validation_0-rmse:0.586490
# [327]	validation_0-rmse:0.586513
# [328]	validation_0-rmse:0.586508
# [329]	validation_0-rmse:0.586465
# [330]	validation_0-rmse:0.586468
# [331]	validation_0-rmse:0.586450
# [332]	validation_0-rmse:0.586413
# [333]	validation_0-rmse:0.586398
# [334]	validation_0-rmse:0.586394
# [335]	validation_0-rmse:0.586361
# [336]	validation_0-rmse:0.586368
# [337]	validation_0-rmse:0.586353
# [338]	validation_0-rmse:0.586356
# [339]	validation_0-rmse:0.586348
# [340]	validation_0-rmse:0.586331
# [341]	validation_0-rmse:0.586327
# [342]	validation_0-rmse:0.586295
# [343]	validation_0-rmse:0.586336
# [344]	validation_0-rmse:0.586305
# [345]	validation_0-rmse:0.586272
# [346]	validation_0-rmse:0.586276
# [347]	validation_0-rmse:0.586269
# [348]	validation_0-rmse:0.586258
# [349]	validation_0-rmse:0.586257
# [350]	validation_0-rmse:0.586248
# [351]	validation_0-rmse:0.586256
# [352]	validation_0-rmse:0.586268
# [353]	validation_0-rmse:0.586252
# [354]	validation_0-rmse:0.586247
# [355]	validation_0-rmse:0.586226
# [356]	validation_0-rmse:0.586144
# [357]	validation_0-rmse:0.586089
# [358]	validation_0-rmse:0.586052
# [359]	validation_0-rmse:0.585993
# [360]	validation_0-rmse:0.585951
# [361]	validation_0-rmse:0.585943
# [362]	validation_0-rmse:0.585904
# [363]	validation_0-rmse:0.585904
# [364]	validation_0-rmse:0.585903
# [365]	validation_0-rmse:0.585881
# [366]	validation_0-rmse:0.585842
# [367]	validation_0-rmse:0.585826
# [368]	validation_0-rmse:0.585829
# [369]	validation_0-rmse:0.585831
# [370]	validation_0-rmse:0.585821
# [371]	validation_0-rmse:0.585801
# [372]	validation_0-rmse:0.585796
# [373]	validation_0-rmse:0.585791
# [374]	validation_0-rmse:0.585806
# [375]	validation_0-rmse:0.585797
# [376]	validation_0-rmse:0.585766
# [377]	validation_0-rmse:0.585759
# [378]	validation_0-rmse:0.585761
# [379]	validation_0-rmse:0.585736
# [380]	validation_0-rmse:0.585700
# [381]	validation_0-rmse:0.585696
# [382]	validation_0-rmse:0.585693
# [383]	validation_0-rmse:0.585672
# [384]	validation_0-rmse:0.585674
# [385]	validation_0-rmse:0.585684
# [386]	validation_0-rmse:0.585697
# [387]	validation_0-rmse:0.585698
# [388]	validation_0-rmse:0.585699
# [389]	validation_0-rmse:0.585636
# [390]	validation_0-rmse:0.585584
# [391]	validation_0-rmse:0.585556
# [392]	validation_0-rmse:0.585555
# [393]	validation_0-rmse:0.585572
# [394]	validation_0-rmse:0.585491
# [395]	validation_0-rmse:0.585516
# [396]	validation_0-rmse:0.585484
# [397]	validation_0-rmse:0.585458
# [398]	validation_0-rmse:0.585468
# [399]	validation_0-rmse:0.585456
# [400]	validation_0-rmse:0.585449
# [401]	validation_0-rmse:0.585442
# [402]	validation_0-rmse:0.585405
# [403]	validation_0-rmse:0.585365
# [404]	validation_0-rmse:0.585362
# [405]	validation_0-rmse:0.585342
# [406]	validation_0-rmse:0.585356
# [407]	validation_0-rmse:0.585352
# [408]	validation_0-rmse:0.585346
# [409]	validation_0-rmse:0.585303
# [410]	validation_0-rmse:0.585294
# [411]	validation_0-rmse:0.585288
# [412]	validation_0-rmse:0.585282
# [413]	validation_0-rmse:0.585264
# [414]	validation_0-rmse:0.585249
# [415]	validation_0-rmse:0.585236
# [416]	validation_0-rmse:0.585225
# [417]	validation_0-rmse:0.585206
# [418]	validation_0-rmse:0.585202
# [419]	validation_0-rmse:0.585221
# [420]	validation_0-rmse:0.585220
# [421]	validation_0-rmse:0.585214
# [422]	validation_0-rmse:0.585209
# [423]	validation_0-rmse:0.585195
# [424]	validation_0-rmse:0.585179
# [425]	validation_0-rmse:0.585170
# [426]	validation_0-rmse:0.585139
# [427]	validation_0-rmse:0.585104
# [428]	validation_0-rmse:0.585091
# [429]	validation_0-rmse:0.585029
# [430]	validation_0-rmse:0.585027
# [431]	validation_0-rmse:0.585023
# [432]	validation_0-rmse:0.585039
# [433]	validation_0-rmse:0.585044
# [434]	validation_0-rmse:0.585020
# [435]	validation_0-rmse:0.585008
# [436]	validation_0-rmse:0.584997
# [437]	validation_0-rmse:0.585013
# [438]	validation_0-rmse:0.585013
# [439]	validation_0-rmse:0.585026
# [440]	validation_0-rmse:0.585012
# [441]	validation_0-rmse:0.585010
# [442]	validation_0-rmse:0.584992
# [443]	validation_0-rmse:0.584996
# [444]	validation_0-rmse:0.584939
# [445]	validation_0-rmse:0.584918
# [446]	validation_0-rmse:0.584909
# [447]	validation_0-rmse:0.584893
# [448]	validation_0-rmse:0.584852
# [449]	validation_0-rmse:0.584848
# [450]	validation_0-rmse:0.584844
# [451]	validation_0-rmse:0.584833
# [452]	validation_0-rmse:0.584829
# [453]	validation_0-rmse:0.584839
# [454]	validation_0-rmse:0.584837
# [455]	validation_0-rmse:0.584788
# [456]	validation_0-rmse:0.584805
# [457]	validation_0-rmse:0.584790
# [458]	validation_0-rmse:0.584795
# [459]	validation_0-rmse:0.584822
# [460]	validation_0-rmse:0.584810
# [461]	validation_0-rmse:0.584812
# [462]	validation_0-rmse:0.584795
# [463]	validation_0-rmse:0.584772
# [464]	validation_0-rmse:0.584773
# [465]	validation_0-rmse:0.584752
# [466]	validation_0-rmse:0.584758
# [467]	validation_0-rmse:0.584737
# [468]	validation_0-rmse:0.584737
# [469]	validation_0-rmse:0.584681
# [470]	validation_0-rmse:0.584654
# [471]	validation_0-rmse:0.584657
# [472]	validation_0-rmse:0.584627
# [473]	validation_0-rmse:0.584637
# [474]	validation_0-rmse:0.584604
# [475]	validation_0-rmse:0.584599
# [476]	validation_0-rmse:0.584563
# [477]	validation_0-rmse:0.584589
# [478]	validation_0-rmse:0.584576
# [479]	validation_0-rmse:0.584550
# [480]	validation_0-rmse:0.584529
# [481]	validation_0-rmse:0.584516
# [482]	validation_0-rmse:0.584518
# [483]	validation_0-rmse:0.584467
# [484]	validation_0-rmse:0.584466
# [485]	validation_0-rmse:0.584439
# [486]	validation_0-rmse:0.584462
# [487]	validation_0-rmse:0.584477
# [488]	validation_0-rmse:0.584445
# [489]	validation_0-rmse:0.584412
# [490]	validation_0-rmse:0.584392
# [491]	validation_0-rmse:0.584395
# [492]	validation_0-rmse:0.584407
# [493]	validation_0-rmse:0.584416
# [494]	validation_0-rmse:0.584430
# [495]	validation_0-rmse:0.584421
# [496]	validation_0-rmse:0.584391
# [497]	validation_0-rmse:0.584379
# [498]	validation_0-rmse:0.584368
# Done!
# [499]	validation_0-rmse:0.584348

# %%
# Score

from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import median_absolute_error
from sklearn.metrics import r2_score

# Print Parameters
print("Parameters")
print()
print("Depth: ", depth)
print("estimator: ", estimator)
print("l_rate: ", l_rate)
print("sub_sample: ", sub_sample)
print("col_sample: ", col_sample)
print("seed: ", seed_val)
print("Alpha: ", alpha_val)
#print("Lambda: ", lambda_val)
# print("Num Rounds: ", n_round)
# print("Verbose Val: ", verbose_val)
print()
print()


# Score On Full Train Set
full_train_pred = clf.predict(X_train)
print(" -- Scores -- Full Train -- ")
print("Explained Variance Score: ", explained_variance_score(y_train, full_train_pred ))
print("Mean Absolute Error: ", mean_absolute_error(y_train, full_train_pred))
print("Mean Squared Error: ", mean_squared_error(y_train, full_train_pred))
print("Median Absolute Error: ", median_absolute_error(y_train, full_train_pred))
print("R2 Score: ", r2_score(y_train, full_train_pred))
print()
print()

# Score On Train Split
split_train_pred = clf.predict(X_fit)
print(" -- Scores -- Train Split -- ")
print("Explained Variance Score: ", explained_variance_score(y_fit, split_train_pred ))
print("Mean Absolute Error: ", mean_absolute_error(y_fit, split_train_pred))
print("Mean Squared Error: ", mean_squared_error(y_fit, split_train_pred))
print("Median Absolute Error: ", median_absolute_error(y_fit, split_train_pred))
print("R2 Score: ", r2_score(y_fit, split_train_pred))
print()
print()

# Score On Test Split
split_test_pred = clf.predict(X_eval)
print(" -- Scores -- Test Split -- ")
print("Explained Variance Score: ", explained_variance_score(y_eval, split_test_pred ))
print("Mean Absolute Error: ", mean_absolute_error(y_eval, split_test_pred))
print("Mean Squared Error: ", mean_squared_error(y_eval, split_test_pred))
print("Median Absolute Error: ", median_absolute_error(y_eval, split_test_pred))
print("R2 Score: ", r2_score(y_eval, split_test_pred))
print()
# Out:
# Parameters
#
# Depth:  10
# estimator:  500
# l_rate:  0.03
# sub_sample:  0.94
# col_sample:  0.85
# seed:  4242
# Alpha:  0.7
#
#
#  -- Scores -- Full Train --
# Explained Variance Score:  0.862163587404
# Mean Absolute Error:  0.173117770576
# Mean Squared Error:  0.0959792715642
# Median Absolute Error:  0.091057761348
# R2 Score:  0.862163431286
#
#
#  -- Scores -- Train Split --
# Explained Variance Score:  0.948601397626
# Mean Absolute Error:  0.124881585651
# Mean Squared Error:  0.0358075900532
# Median Absolute Error:  0.0794050165003
# R2 Score:  0.948601068028
#
#
#  -- Scores -- Test Split --
# Explained Variance Score:  0.515597307879
# Mean Absolute Error:  0.366062510275
# Mean Squared Error:  0.336665997608
# Median Absolute Error:  0.204168595975
# R2 Score:  0.515579017913

# %%
# Score on Test File From 9th Place Prediction

# %%
# Write To File
import csv

write_file = open('predictions_1.csv', 'w')
write_file.write('ID,Prediction\n')
for x,y in enumerate(y_pred):
    write_file.write('{},{} \n'.format(x+1, y))
    
                     
write_file.close()

print(y_pred.shape)

print('Completed!')
# Out:
# (40000,)
# Completed!
