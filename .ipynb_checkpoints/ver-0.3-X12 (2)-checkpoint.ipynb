# %%
# Results

# Both Feature Sets
# [349]	validation_0-rmse:0.544184
# [160]	validation_0-rmse:0.536579

# Single Feature Set
# [160]	validation_0-rmse:0.561419

# 9th place  max_depth=20, n_estimators=161, learning_rate=0.03, nthread=4, subsample=0.95, colsample_bytree=0.85, seed=4242 )
#[160]	validation_0-rmse:0.118262

# %%
# Iris Data

from sklearn.cross_validation import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.pipeline import Pipeline
from sklearn.svm import OneClassSVM
import sklearn.linear_model as lm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import xgboost as xgb

# Data Files

# load data
df_train_1 = pd.read_csv('./data/kaggle.X1.train.txt', header=None)
df_train_2 = pd.read_csv('./data/kaggle.X2.train.txt', header=None)
df_train_Y = pd.read_csv('./data/kaggle.Y.train.txt', header=None)
df_test_1 = pd.read_csv('./data/kaggle.X1.test.txt', header=None)
df_test_2 = pd.read_csv('./data/kaggle.X2.test.txt', header=None)

# Combine Train Data 
df_train_X = pd.concat([df_train_1, df_train_2], axis=1)

# Combine Test Data 
df_test_X = pd.concat([df_test_1, df_test_2], axis=1)


# Create Numpy Arrays
X_train = df_train_X.values
y_train = df_train_Y.values
X_test = df_test_X.values

# Use Only X1
# X_train = df_train_1.values
# X_test = df_test_1.values

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
# Out:
# (60000, 532)
# (60000, 1)
# (40000, 532)

# %%
# Train Model

depth = 9
estimator = 10000
l_rate = 0.03
sub_sample = 0.9
col_sample = 0.8
seed_val = 4242
# n_round = 2
# verbose_val = 2
alpha_val = 0.8
min_child_val = 7
#lambda_val = 1.0

# classifier XBG Regression
clf = xgb.XGBRegressor(missing=np.nan, max_depth=depth, n_estimators=estimator, 
                       learning_rate=l_rate, nthread=12, subsample=sub_sample, colsample_bytree=col_sample, 
                       seed=seed_val, reg_alpha = alpha_val, min_child_weight=min_child_val)

X_fit, X_eval, y_fit, y_eval= train_test_split(X_train, y_train, test_size=0.2)

# fitting
# !! I Changed the fit paremeters to (X_fit, y_fit, )
clf.fit(X_fit, y_fit, early_stopping_rounds=20, eval_metric="rmse", eval_set=[(X_eval, y_eval)])

# predicting
y_pred= clf.predict(X_test)

print("Done!")
# Out:
# Will train until validation_0 error hasn't decreased in 20 rounds.
# [0]	validation_0-rmse:0.824304
# [1]	validation_0-rmse:0.813929
# [2]	validation_0-rmse:0.804146
# [3]	validation_0-rmse:0.795123
# [4]	validation_0-rmse:0.786121
# [5]	validation_0-rmse:0.777400
# [6]	validation_0-rmse:0.769148
# [7]	validation_0-rmse:0.761062
# [8]	validation_0-rmse:0.753184
# [9]	validation_0-rmse:0.746110
# [10]	validation_0-rmse:0.739206
# [11]	validation_0-rmse:0.732544
# [12]	validation_0-rmse:0.726213
# [13]	validation_0-rmse:0.720068
# [160]	validation_0-rmse:0.587485
# [161]	validation_0-rmse:0.587451
# [162]	validation_0-rmse:0.587391
# [163]	validation_0-rmse:0.587480
# [164]	validation_0-rmse:0.587538
# [165]	validation_0-rmse:0.587507
# [166]	validation_0-rmse:0.587442
# [167]	validation_0-rmse:0.587376
# [168]	validation_0-rmse:0.587300
# [169]	validation_0-rmse:0.587235
# [170]	validation_0-rmse:0.587208
# [171]	validation_0-rmse:0.587121
# [172]	validation_0-rmse:0.587002
# [173]	validation_0-rmse:0.586924
# [174]	validation_0-rmse:0.586922
# [175]	validation_0-rmse:0.586812
# [176]	validation_0-rmse:0.586685
# [177]	validation_0-rmse:0.586643
# [178]	validation_0-rmse:0.586523
# [179]	validation_0-rmse:0.586446
# [180]	validation_0-rmse:0.586390
# [181]	validation_0-rmse:0.586428
# [182]	validation_0-rmse:0.586413
# [183]	validation_0-rmse:0.586417
# [184]	validation_0-rmse:0.586417
# [185]	validation_0-rmse:0.586385
# [186]	validation_0-rmse:0.586434
# [187]	validation_0-rmse:0.586313
# [188]	validation_0-rmse:0.586285
# [189]	validation_0-rmse:0.586263
# [190]	validation_0-rmse:0.586271
# [191]	validation_0-rmse:0.586245
# [192]	validation_0-rmse:0.586219
# [193]	validation_0-rmse:0.586179
# [194]	validation_0-rmse:0.586145
# [195]	validation_0-rmse:0.586074
# [196]	validation_0-rmse:0.585960
# [197]	validation_0-rmse:0.585912
# [198]	validation_0-rmse:0.585894
# [199]	validation_0-rmse:0.585790
# [200]	validation_0-rmse:0.585739
# [201]	validation_0-rmse:0.585661
# [202]	validation_0-rmse:0.585637
# [203]	validation_0-rmse:0.585529
# [204]	validation_0-rmse:0.585510
# [205]	validation_0-rmse:0.585438
# [206]	validation_0-rmse:0.585393
# [207]	validation_0-rmse:0.585356
# [208]	validation_0-rmse:0.585319
# [209]	validation_0-rmse:0.585290
# [210]	validation_0-rmse:0.585169
# [211]	validation_0-rmse:0.585128
# [212]	validation_0-rmse:0.585073
# [213]	validation_0-rmse:0.584984
# [214]	validation_0-rmse:0.584931
# [215]	validation_0-rmse:0.584837
# [216]	validation_0-rmse:0.584817

# %%
# Score

from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import median_absolute_error
from sklearn.metrics import r2_score

# Print Parameters
print("Parameters")
print()
print("Depth: ", depth)
print("estimator: ", estimator)
print("l_rate: ", l_rate)
print("sub_sample: ", sub_sample)
print("col_sample: ", col_sample)
print("seed: ", seed_val)
print("Alpha: ", alpha_val)
#print("Lambda: ", lambda_val)
# print("Num Rounds: ", n_round)
# print("Verbose Val: ", verbose_val)
print()
print()


# Score On Full Train Set
full_train_pred = clf.predict(X_train)
print(" -- Scores -- Full Train -- ")
print("Explained Variance Score: ", explained_variance_score(y_train, full_train_pred ))
print("Mean Absolute Error: ", mean_absolute_error(y_train, full_train_pred))
print("Mean Squared Error: ", mean_squared_error(y_train, full_train_pred))
print("Median Absolute Error: ", median_absolute_error(y_train, full_train_pred))
print("R2 Score: ", r2_score(y_train, full_train_pred))
print()
print()

# Score On Train Split
split_train_pred = clf.predict(X_fit)
print(" -- Scores -- Train Split -- ")
print("Explained Variance Score: ", explained_variance_score(y_fit, split_train_pred ))
print("Mean Absolute Error: ", mean_absolute_error(y_fit, split_train_pred))
print("Mean Squared Error: ", mean_squared_error(y_fit, split_train_pred))
print("Median Absolute Error: ", median_absolute_error(y_fit, split_train_pred))
print("R2 Score: ", r2_score(y_fit, split_train_pred))
print()
print()

# Score On Test Split
split_test_pred = clf.predict(X_eval)
print(" -- Scores -- Test Split -- ")
print("Explained Variance Score: ", explained_variance_score(y_eval, split_test_pred ))
print("Mean Absolute Error: ", mean_absolute_error(y_eval, split_test_pred))
print("Mean Squared Error: ", mean_squared_error(y_eval, split_test_pred))
print("Median Absolute Error: ", median_absolute_error(y_eval, split_test_pred))
print("R2 Score: ", r2_score(y_eval, split_test_pred))
print()
# Out:
# Parameters
# ()
# ('Depth: ', 9)
# ('estimator: ', 10000)
# ('l_rate: ', 0.03)
# ('sub_sample: ', 0.9)
# ('col_sample: ', 0.8)
# ('seed: ', 4242)
# ('Alpha: ', 0.8)
# ()
# ()
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# <ipython-input-129-4ae2a540e90f> in <module>()
#      25
#      26 # Score On Full Train Set
# ---> 27 full_train_pred = clf.predict(X_train)
#      28 print(" -- Scores -- Full Train -- ")
#      29 print("Explained Variance Score: ", explained_variance_score(y_train, full_train_pred ))
#
# /usr/local/lib/python2.7/dist-packages/xgboost-0.4a30-py2.7.egg/xgboost/sklearn.pyc in predict(self, data, output_margin, ntree_limit)
#     202         # pylint: disable=missing-docstring,invalid-name
#     203         test_dmatrix = DMatrix(data, missing=self.missing)
# --> 204         return self.booster().predict(test_dmatrix,
#     205                                       output_margin=output_margin,
#     206                                       ntree_limit=ntree_limit)
#
# /usr/local/lib/python2.7/dist-packages/xgboost-0.4a30-py2.7.egg/xgboost/sklearn.pyc in booster(self)
#     107         """
#     108         if self._Booster is None:
# --> 109             raise XGBoostError('need to call fit beforehand')
#     110         return self._Booster
#     111
#
# XGBoostError: need to call fit beforehand

# %%
# Score on Test File From 9th Place Prediction

# %%
# Write To File
import csv

write_file = open('predictions_1.csv', 'w')
write_file.write('ID,Prediction\n')
for x,y in enumerate(y_pred):
    write_file.write('{},{} \n'.format(x+1, y))
    
                     
write_file.close()

print(y_pred.shape)

print('Completed!')
# Out:
# (40000,)
# Completed!
