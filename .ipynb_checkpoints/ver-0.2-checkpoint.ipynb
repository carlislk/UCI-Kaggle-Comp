# %%
# Results

# Both Feature Sets
# [349]	validation_0-rmse:0.544184
# [160]	validation_0-rmse:0.536579

# Single Feature Set
# [160]	validation_0-rmse:0.561419

# 9th place  max_depth=20, n_estimators=161, learning_rate=0.03, nthread=4, subsample=0.95, colsample_bytree=0.85, seed=4242 )
#[160]	validation_0-rmse:0.118262

# %%
# Iris Data

from sklearn.cross_validation import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.pipeline import Pipeline
from sklearn.svm import OneClassSVM
import sklearn.linear_model as lm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import xgboost as xgb

# Data Files

# load data
df_train_1 = pd.read_csv('./data/kaggle.X1.train.txt', header=None)
df_train_2 = pd.read_csv('./data/kaggle.X2.train.txt', header=None)
df_train_Y = pd.read_csv('./data/kaggle.Y.train.txt', header=None)
df_test_1 = pd.read_csv('./data/kaggle.X1.test.txt', header=None)
df_test_2 = pd.read_csv('./data/kaggle.X1.test.txt', header=None)

# # Combine Train Data 
# df_train_X = pd.concat([df_train_1, df_train_2], axis=1)

# # Combine Test Data 
# df_test_X = pd.concat([df_test_1, df_test_2], axis=1)


# Create Numpy Arrays
# X_train = df_train_X.values
y_train = df_train_Y.values
# X_test = df_test_X.values

X_train = df_train_1.values
X_test = df_test_1.values

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
# Out:
# (60000, 91)
# (60000, 1)
# (40000, 91)

# %%
# Train Model

depth = 10
estimator = 161
l_rate = 0.03
sub_sample = 0.94
col_sample = 0.85
seed_val = 4242
# n_round = 2
# verbose_val = 2
alpha_val = 0.7
lambda_val = 0.3

# classifier XBG Regression
clf = xgb.XGBRegressor(missing=np.nan, max_depth=depth, n_estimators=estimator, 
                       learning_rate=l_rate, nthread=4, subsample=sub_sample, colsample_bytree=col_sample, 
                       seed=seed_val, reg_alpha = alpha_val, reg_lambda = lambda_val)

X_fit, X_eval, y_fit, y_eval= train_test_split(X_train, y_train, test_size=0.3)

# fitting
# !! I Changed the fit paremeters to (X_fit, y_fit, )
clf.fit(X_fit, y_fit, early_stopping_rounds=20, eval_metric="rmse", eval_set=[(X_eval, y_eval)])

# predicting
y_pred= clf.predict(X_test)

print("Done!")
# Out:
# Will train until validation_0 error hasn't decreased in 20 rounds.
# [0]	validation_0-rmse:0.836094
# [1]	validation_0-rmse:0.825560
# [2]	validation_0-rmse:0.815529
# [3]	validation_0-rmse:0.805964
# [4]	validation_0-rmse:0.796895
# [5]	validation_0-rmse:0.788084
# [6]	validation_0-rmse:0.779805
# [7]	validation_0-rmse:0.771814
# [8]	validation_0-rmse:0.764362
# [9]	validation_0-rmse:0.757139
# [10]	validation_0-rmse:0.750231
# [11]	validation_0-rmse:0.743614
# [12]	validation_0-rmse:0.737334
# [13]	validation_0-rmse:0.731216
# [14]	validation_0-rmse:0.725531
# [15]	validation_0-rmse:0.720178
# [16]	validation_0-rmse:0.714885
# [17]	validation_0-rmse:0.709770
# [18]	validation_0-rmse:0.704900
# [19]	validation_0-rmse:0.700114
# [20]	validation_0-rmse:0.695822
# [21]	validation_0-rmse:0.691641
# [22]	validation_0-rmse:0.687715
# [23]	validation_0-rmse:0.684083
# [24]	validation_0-rmse:0.680524
# [25]	validation_0-rmse:0.677157
# [26]	validation_0-rmse:0.673981
# [27]	validation_0-rmse:0.670823
# [28]	validation_0-rmse:0.667736
# [29]	validation_0-rmse:0.664796
# [30]	validation_0-rmse:0.662005
# [31]	validation_0-rmse:0.659309
# [32]	validation_0-rmse:0.656860
# [33]	validation_0-rmse:0.654761
# [34]	validation_0-rmse:0.652522
# [35]	validation_0-rmse:0.650403
# [36]	validation_0-rmse:0.648346
# [37]	validation_0-rmse:0.646338
# [38]	validation_0-rmse:0.644402
# [39]	validation_0-rmse:0.642524
# [40]	validation_0-rmse:0.640820
# [41]	validation_0-rmse:0.639232
# [42]	validation_0-rmse:0.637567
# [43]	validation_0-rmse:0.636077
# [44]	validation_0-rmse:0.634726
# [45]	validation_0-rmse:0.633431
# [46]	validation_0-rmse:0.632151
# [47]	validation_0-rmse:0.630856
# [48]	validation_0-rmse:0.629769
# [49]	validation_0-rmse:0.628582
# [50]	validation_0-rmse:0.627378
# [51]	validation_0-rmse:0.626372
# [52]	validation_0-rmse:0.625440
# [53]	validation_0-rmse:0.624384
# [54]	validation_0-rmse:0.623327
# [55]	validation_0-rmse:0.622478
# [56]	validation_0-rmse:0.621590
# [57]	validation_0-rmse:0.620653
# [58]	validation_0-rmse:0.619869
# [59]	validation_0-rmse:0.618976
# [60]	validation_0-rmse:0.618237
# [61]	validation_0-rmse:0.617560
# [62]	validation_0-rmse:0.616814
# [63]	validation_0-rmse:0.616055
# [64]	validation_0-rmse:0.615475
# [65]	validation_0-rmse:0.615006
# [66]	validation_0-rmse:0.614413
# [67]	validation_0-rmse:0.613837
# [68]	validation_0-rmse:0.613199
# [69]	validation_0-rmse:0.612758
# [70]	validation_0-rmse:0.612219
# [71]	validation_0-rmse:0.611822
# [72]	validation_0-rmse:0.611311
# [73]	validation_0-rmse:0.610900
# [74]	validation_0-rmse:0.610497
# [75]	validation_0-rmse:0.610057
# [76]	validation_0-rmse:0.609660
# [77]	validation_0-rmse:0.609275
# [78]	validation_0-rmse:0.608934
# [79]	validation_0-rmse:0.608614
# [80]	validation_0-rmse:0.608384
# [81]	validation_0-rmse:0.608136
# [82]	validation_0-rmse:0.607855
# [83]	validation_0-rmse:0.607670
# [84]	validation_0-rmse:0.607321
# [85]	validation_0-rmse:0.606979
# [86]	validation_0-rmse:0.606737
# [87]	validation_0-rmse:0.606539
# [88]	validation_0-rmse:0.606302
# [89]	validation_0-rmse:0.606150
# [90]	validation_0-rmse:0.605872
# [91]	validation_0-rmse:0.605701
# [92]	validation_0-rmse:0.605514
# [93]	validation_0-rmse:0.605338
# [94]	validation_0-rmse:0.605172
# [95]	validation_0-rmse:0.604970
# [96]	validation_0-rmse:0.604902
# [97]	validation_0-rmse:0.604728
# [98]	validation_0-rmse:0.604523
# [99]	validation_0-rmse:0.604349
# [100]	validation_0-rmse:0.604097
# [101]	validation_0-rmse:0.603969
# [102]	validation_0-rmse:0.603791
# [103]	validation_0-rmse:0.603660
# [104]	validation_0-rmse:0.603448
# [105]	validation_0-rmse:0.603280
# [106]	validation_0-rmse:0.603088
# [107]	validation_0-rmse:0.602958
# [108]	validation_0-rmse:0.602876
# [109]	validation_0-rmse:0.602807
# [110]	validation_0-rmse:0.602671
# [111]	validation_0-rmse:0.602593
# [112]	validation_0-rmse:0.602377
# [113]	validation_0-rmse:0.602282
# [114]	validation_0-rmse:0.602188
# [115]	validation_0-rmse:0.602150
# [116]	validation_0-rmse:0.601953
# [117]	validation_0-rmse:0.601775
# [118]	validation_0-rmse:0.601696
# [119]	validation_0-rmse:0.601499
# [120]	validation_0-rmse:0.601356
# [121]	validation_0-rmse:0.601228
# [122]	validation_0-rmse:0.601137
# [123]	validation_0-rmse:0.600984
# [124]	validation_0-rmse:0.600796
# [125]	validation_0-rmse:0.600657
# [126]	validation_0-rmse:0.600561
# [127]	validation_0-rmse:0.600453
# [128]	validation_0-rmse:0.600395
# [129]	validation_0-rmse:0.600268
# [130]	validation_0-rmse:0.600137
# [131]	validation_0-rmse:0.600097
# [132]	validation_0-rmse:0.599915
# [133]	validation_0-rmse:0.599830
# [134]	validation_0-rmse:0.599729
# [135]	validation_0-rmse:0.599623
# [136]	validation_0-rmse:0.599575
# [137]	validation_0-rmse:0.599450
# [138]	validation_0-rmse:0.599341
# [139]	validation_0-rmse:0.599285
# [140]	validation_0-rmse:0.599188
# [141]	validation_0-rmse:0.599161
# [142]	validation_0-rmse:0.599157
# [143]	validation_0-rmse:0.599128
# [144]	validation_0-rmse:0.599028
# [145]	validation_0-rmse:0.598956
# [146]	validation_0-rmse:0.598837
# [147]	validation_0-rmse:0.598783
# [148]	validation_0-rmse:0.598686
# [149]	validation_0-rmse:0.598609
# [150]	validation_0-rmse:0.598540
# [151]	validation_0-rmse:0.598491
# [152]	validation_0-rmse:0.598454
# [153]	validation_0-rmse:0.598416
# [154]	validation_0-rmse:0.598352
# [155]	validation_0-rmse:0.598320
# [156]	validation_0-rmse:0.598287
# [157]	validation_0-rmse:0.598206
# [158]	validation_0-rmse:0.598132
# [159]	validation_0-rmse:0.598090
# [160]	validation_0-rmse:0.598001
# Done!

# %%
# Score

from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import median_absolute_error
from sklearn.metrics import r2_score

# Print Parameters
print("Parameters")
print()
print("Depth: ", depth)
print("estimator: ", estimator)
print("l_rate: ", l_rate)
print("sub_sample: ", sub_sample)
print("col_sample: ", col_sample)
print("seed: ", seed_val)
print("Alpha: ", alpha_val)
# print("Num Rounds: ", n_round)
# print("Verbose Val: ", verbose_val)
print()
print()


# Score On Full Train Set
full_train_pred = clf.predict(X_train)
print(" -- Scores -- Full Train -- ")
print("Explained Variance Score: ", explained_variance_score(y_train, full_train_pred ))
print("Mean Absolute Error: ", mean_absolute_error(y_train, full_train_pred))
print("Mean Squared Error: ", mean_squared_error(y_train, full_train_pred))
print("Median Absolute Error: ", median_absolute_error(y_train, full_train_pred))
print("R2 Score: ", r2_score(y_train, full_train_pred))
print()
print()

# Score On Train Split
split_train_pred = clf.predict(X_fit)
print(" -- Scores -- Train Split -- ")
print("Explained Variance Score: ", explained_variance_score(y_fit, split_train_pred ))
print("Mean Absolute Error: ", mean_absolute_error(y_fit, split_train_pred))
print("Mean Squared Error: ", mean_squared_error(y_fit, split_train_pred))
print("Median Absolute Error: ", median_absolute_error(y_fit, split_train_pred))
print("R2 Score: ", r2_score(y_fit, split_train_pred))
print()
print()

# Score On Test Split
split_test_pred = clf.predict(X_eval)
print(" -- Scores -- Test Split -- ")
print("Explained Variance Score: ", explained_variance_score(y_eval, split_test_pred ))
print("Mean Absolute Error: ", mean_absolute_error(y_eval, split_test_pred))
print("Mean Squared Error: ", mean_squared_error(y_eval, split_test_pred))
print("Median Absolute Error: ", median_absolute_error(y_eval, split_test_pred))
print("R2 Score: ", r2_score(y_eval, split_test_pred))
print()
# Out:
# Parameters
#
# Depth:  10
# estimator:  161
# l_rate:  0.03
# sub_sample:  0.94
# col_sample:  0.85
# seed:  4242
# Alpha:  0.6
#
#
#  -- Scores -- Full Train --
# Explained Variance Score:  0.745479724721
# Mean Absolute Error:  0.25837844617
# Mean Squared Error:  0.177232786873
# Median Absolute Error:  0.149768289056
# R2 Score:  0.745474634178
#
#
#  -- Scores -- Train Split --
# Explained Variance Score:  0.853862998585
# Mean Absolute Error:  0.208674730395
# Mean Squared Error:  0.101270625227
# Median Absolute Error:  0.132733911108
# R2 Score:  0.853853455848
#
#
#  -- Scores -- Test Split --
# Explained Variance Score:  0.496628750894
# Mean Absolute Error:  0.37435378298
# Mean Squared Error:  0.354477830712
# Median Absolute Error:  0.207981015845
# R2 Score:  0.496628643001

# %%
# Score on Test File From 9th Place Prediction

# %%
# Write To File
import csv

write_file = open('predictions_1.csv', 'w')
write_file.write('ID,Prediction\n')
for x,y in enumerate(y_pred):
    write_file.write('{},{} \n'.format(x+1, y))
    
                     
write_file.close()

print(y_pred.shape)

print('Completed!')
# Out:
# (40000,)
# Completed!
