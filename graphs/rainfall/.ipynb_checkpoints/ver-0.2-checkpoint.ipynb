# %%
# Results

# Both Feature Sets
# [349]	validation_0-rmse:0.544184
# [160]	validation_0-rmse:0.536579

# Single Feature Set
# [160]	validation_0-rmse:0.561419

# 9th place  max_depth=20, n_estimators=161, learning_rate=0.03, nthread=4, subsample=0.95, colsample_bytree=0.85, seed=4242 )
#[160]	validation_0-rmse:0.118262

# %%
# Iris Data

from sklearn.cross_validation import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.pipeline import Pipeline
from sklearn.svm import OneClassSVM
import sklearn.linear_model as lm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import xgboost as xgb

# Data Files

# load data
df_train_1 = pd.read_csv('./data/kaggle.X1.train.txt', header=None)
df_train_2 = pd.read_csv('./data/kaggle.X2.train.txt', header=None)
df_train_Y = pd.read_csv('./data/kaggle.Y.train.txt', header=None)
df_test_1 = pd.read_csv('./data/kaggle.X1.test.txt', header=None)
df_test_2 = pd.read_csv('./data/kaggle.X2.test.txt', header=None)

# # Combine Train Data 
# df_train_X = pd.concat([df_train_1, df_train_2], axis=1)

# # Combine Test Data 
# df_test_X = pd.concat([df_test_1, df_test_2], axis=1)


# Create Numpy Arrays
# X_train = df_train_X.values
y_train = df_train_Y.values
# X_test = df_test_X.values

X_train = df_train_1.values
X_test = df_test_1.values

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
# Out:
# (60000, 91)
# (60000, 1)
# (40000, 91)

# %%
from collections import defaultdict
from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import median_absolute_error
from sklearn.metrics import r2_score

# Train Model

depth = 10
depth_vals = [6,8,10,12]
estimator = 500
estimator_vals = [1,100,200,300,400,500,600,700,800,900,1000]
l_rate = 0.03
sub_sample = 0.94
col_sample = 0.85
seed_val = 4242
# n_round = 2
# verbose_val = 2
alpha_vals = [0, 0.25, 0.5, 0.75, 1]
#lambda_val = 1.0

#[[depth, estimator, alpha, var, abs, mse, mae, r2], ... ]
f_tr_err = []
s_tr_err = []
s_te_err = []
'''
for i in depth_vals:
    for j in estimator_vals:
        for k in alpha_vals:
            print("Params:\n\tdepth: {0}\n\tn_estimators: {1}\n\talpha_val: {2}".format(i,j,k))
            # classifier XBG Regression
            clf = xgb.XGBRegressor(missing=np.nan, max_depth=i, n_estimators=j, 
                       learning_rate=l_rate, nthread=12, subsample=sub_sample, colsample_bytree=col_sample, 
                       seed=seed_val, reg_alpha=k)

            X_fit, X_eval, y_fit, y_eval= train_test_split(X_train, y_train, test_size=0.2)

            # fitting
            # !! I Changed the fit paremeters to (X_fit, y_fit, )
            clf.fit(X_fit, y_fit, early_stopping_rounds=20, eval_metric="rmse", eval_set=[(X_eval, y_eval)])

            # predicting
            y_pred= clf.predict(X_test)
            full_train_pred = clf.predict(X_train)
            split_train_pred = clf.predict(X_fit)
            split_test_pred = clf.predict(X_eval)
            
            #Calculate errors for full train set
            fto = []
            fto.append(i)
            fto.append(j)
            fto.append(k)
            fto.append(explained_variance_score(y_train, full_train_pred))
            fto.append(mean_absolute_error(y_train, full_train_pred))
            fto.append(mean_squared_error(y_train, full_train_pred))
            fto.append(median_absolute_error(y_train, full_train_pred))
            fto.append(r2_score(y_train, full_train_pred))
            f_tr_err.append(fto)
            
            #Calculate errors on train split
            stro = []
            stro.append(i)
            stro.append(j)
            stro.append(k)
            stro.append(explained_variance_score(y_fit, split_train_pred))
            stro.append(mean_absolute_error(y_fit, split_train_pred))
            stro.append(mean_squared_error(y_fit, split_train_pred))
            stro.append(median_absolute_error(y_fit, split_train_pred))
            stro.append(r2_score(y_fit, split_train_pred))
            s_tr_err.append(stro)
            
            #Calculate errors on test split
            steo = []
            steo.append(i)
            steo.append(j)
            steo.append(k)
            steo.append(explained_variance_score(y_eval, split_test_pred))
            steo.append(mean_absolute_error(y_eval, split_test_pred))
            steo.append(mean_squared_error(y_eval, split_test_pred))
            steo.append(median_absolute_error(y_eval, split_test_pred))
            steo.append(r2_score(y_eval, split_test_pred))
            s_te_err.append(steo)
            '''

print("Done!")
# Out:
# Done!

# %%
### Score

from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import median_absolute_error
from sklearn.metrics import r2_score

# Print Parameters
print("Parameters")
print()
print("Depth: ", depth)
print("estimator: ", estimator)
print("l_rate: ", l_rate)
print("sub_sample: ", sub_sample)
print("col_sample: ", col_sample)
print("seed: ", seed_val)
print("Alpha: ", alpha_val)
#print("Lambda: ", lambda_val)
# print("Num Rounds: ", n_round)
# print("Verbose Val: ", verbose_val)
print()
print()


# Score On Full Train Set
full_train_pred = clf.predict(X_train)
print(" -- Scores -- Full Train -- ")
print("Explained Variance Score: ", explained_variance_score(y_train, full_train_pred ))
print("Mean Absolute Error: ", mean_absolute_error(y_train, full_train_pred))
print("Mean Squared Error: ", mean_squared_error(y_train, full_train_pred))
print("Median Absolute Error: ", median_absolute_error(y_train, full_train_pred))
print("R2 Score: ", r2_score(y_train, full_train_pred))
print()
print()

# Score On Train Split
split_train_pred = clf.predict(X_fit)
print(" -- Scores -- Train Split -- ")
print("Explained Variance Score: ", explained_variance_score(y_fit, split_train_pred ))
print("Mean Absolute Error: ", mean_absolute_error(y_fit, split_train_pred))
print("Mean Squared Error: ", mean_squared_error(y_fit, split_train_pred))
print("Median Absolute Error: ", median_absolute_error(y_fit, split_train_pred))
print("R2 Score: ", r2_score(y_fit, split_train_pred))
print()
print()

# Score On Test Split
split_test_pred = clf.predict(X_eval)
print(" -- Scores -- Test Split -- ")
print("Explained Variance Score: ", explained_variance_score(y_eval, split_test_pred ))
print("Mean Absolute Error: ", mean_absolute_error(y_eval, split_test_pred))
print("Mean Squared Error: ", mean_squared_error(y_eval, split_test_pred))
print("Median Absolute Error: ", median_absolute_error(y_eval, split_test_pred))
print("R2 Score: ", r2_score(y_eval, split_test_pred))
print()

# %%
# Score on Test File From 9th Place Prediction

# %%
# Write To File
import csv

write_file = open('predictions_1.csv', 'w')
write_file.write('ID,Prediction\n')
for x,y in enumerate(y_pred):
    write_file.write('{},{} \n'.format(x+1, y))
    
                     
write_file.close()

print(y_pred.shape)

print('Completed!')
# Out:
# (40000,)
# Completed!

# %%
import csv

with open('data/f_tr_err.csv', 'w') as csvfile:
    writer = csv.writer(csvfile)
    for data in f_tr_err:
        writer.writerow(data)

with open('data/s_tr_err.csv', 'w') as csvfile:
    writer = csv.writer(csvfile)
    for data in s_tr_err:
        writer.writerow(data)
        
with open('data/s_te_err.csv', 'w') as csvfile:
    writer = csv.writer(csvfile)
    for data in s_te_err:
        writer.writerow(data)

# %%
from operator import itemgetter
from itertools import groupby

print("Config for Optimized Explained Variance\n-------------------------")
s_te_err.sort(key=itemgetter(3))
s_te_err_sorted = groupby(s_te_err, itemgetter(3))

for elt, items in s_te_err_sorted:
    print("\tValue: {0}".format(elt))
    for i in items:
        print("\tdepth: {0}\n\tn_estimators: {1}\n\talpha: {2}\n".format(i[0], i[1], i[2]))
        break
    break

print("Config for Optimized Mean Absolute Error\n-------------------------")
s_te_err.sort(key=itemgetter(4))
s_te_err_sorted = groupby(s_te_err, itemgetter(4))

for elt, items in s_te_err_sorted:
    print("\tValue: {0}".format(elt))
    for i in items:
        print("\tdepth: {0}\n\tn_estimators: {1}\n\talpha: {2}\n".format(i[0], i[1], i[2]))
        break
    break

print("Config for Optimized Mean Squared Error\n-------------------------")
s_te_err.sort(key=itemgetter(5))
s_te_err_sorted = groupby(s_te_err, itemgetter(5))

for elt, items in s_te_err_sorted:
    print("\tValue: {0}".format(elt))
    for i in items:
        print("\tdepth: {0}\n\tn_estimators: {1}\n\talpha: {2}\n".format(i[0], i[1], i[2]))
        break
    break
    
print("Config for Optimized Median Absolute Error\n-------------------------")
s_te_err.sort(key=itemgetter(6))
s_te_err_sorted = groupby(s_te_err, itemgetter(6))

for elt, items in s_te_err_sorted:
    print("\tValue: {0}".format(elt))
    for i in items:
        print("\tdepth: {0}\n\tn_estimators: {1}\n\talpha: {2}\n".format(i[0], i[1], i[2]))
        break
    break
    
print("Config for Optimized R2 Score\n-------------------------")
s_te_err.sort(key=itemgetter(7))
s_te_err_sorted = groupby(s_te_err, itemgetter(7))

for elt, items in s_te_err_sorted:
    print("\tValue: {0}".format(elt))
    for i in items:
        print("\tdepth: {0}\n\tn_estimators: {1}\n\talpha: {2}\n".format(i[0], i[1], i[2]))
        break
    break
# Out:
# Config for Optimized Explained Variance
# -------------------------
# 	Value: 0.0226119167854
# 	depth: 6
# 	n_estimators: 1
# 	alpha: 0.5
#
# Config for Optimized Mean Absolute Error
# -------------------------
# 	Value: 0.355720208346
# 	depth: 10
# 	n_estimators: 800
# 	alpha: 0.5
#
# Config for Optimized Mean Squared Error
# -------------------------
# 	Value: 0.324150830668
# 	depth: 10
# 	n_estimators: 800
# 	alpha: 0.5
#
# Config for Optimized Median Absolute Error
# -------------------------
# 	Value: 0.191383825634
# 	depth: 12
# 	n_estimators: 900
# 	alpha: 1
#
# Config for Optimized R2 Score
# -------------------------
# 	Value: 0.00399734590844
# 	depth: 8
# 	n_estimators: 1
# 	alpha: 0

# %%
# classifier XBG Regression
clf = xgb.XGBRegressor(missing=np.nan, max_depth=8, n_estimators=1, 
            learning_rate=l_rate, nthread=12, subsample=sub_sample, colsample_bytree=col_sample, 
            seed=seed_val, reg_alpha=0.5)

X_fit, X_eval, y_fit, y_eval= train_test_split(X_train, y_train, test_size=0.2)

# fitting
# !! I Changed the fit paremeters to (X_fit, y_fit, )
clf.fit(X_fit, y_fit, early_stopping_rounds=20, eval_metric="rmse", eval_set=[(X_eval, y_eval)])

# predicting
y_pred= clf.predict(X_test)

write_file = open('predictions_1.csv', 'w')
write_file.write('ID,Prediction\n')
for x,y in enumerate(y_pred):
    write_file.write('{},{} \n'.format(x+1, y))
    
                     
write_file.close()

print(y_pred.shape)

print('Completed!')
# Out:
# Will train until validation_0 error hasn't decreased in 20 rounds.
# (40000,)
# Completed!
# [0]	validation_0-rmse:0.823555

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from collections import defaultdict
from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import median_absolute_error
from sklearn.metrics import r2_score


# Combine Train Data 
df_train_X = pd.concat([df_train_1, df_train_2], axis=1)

# Combine Test Data 
df_test_X = pd.concat([df_test_1, df_test_2], axis=1)


# Create Numpy Arrays
X_train = df_train_X.values
y_train = df_train_Y.values
#X_train = df_train_1.values
#X_test = df_test_1.values
X_test = df_test_X.values

print(X_train.shape)
print(X_test.shape)

selectK = SelectKBest(f_classif, k=50)
selectK.fit(X_train, y_train)
X_sel = selectK.transform(X_train)

X_fit, X_eval, y_fit, y_eval= train_test_split(X_sel, y_train, random_state=1301, test_size=0.2)

# classifier XBG Regression
clf = xgb.XGBRegressor(missing=np.nan, max_depth=10, n_estimators=800, 
            learning_rate=l_rate, nthread=12, subsample=sub_sample, colsample_bytree=col_sample, 
            seed=seed_val, reg_alpha=0.7)

clf.fit(X_fit, y_fit, early_stopping_rounds=50, eval_metric="rmse", eval_set=[(X_eval, y_eval)])

sel_test = selectK.transform(X_test)
y_pred = clf.predict(sel_test)

write_file = open('predictions_1.csv', 'w')
write_file.write('ID,Prediction\n')
for x,y in enumerate(y_pred):
    write_file.write('{},{} \n'.format(x+1, y))
                     
write_file.close()

print(y_pred.shape)

print('Completed!')
# Out:
# (60000, 532)
# (40000, 532)
# /usr/local/lib/python2.7/dist-packages/sklearn/utils/validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Will train until validation_0 error hasn't decreased in 50 rounds.
# [0]	validation_0-rmse:0.842568
# [1]	validation_0-rmse:0.833678
# [2]	validation_0-rmse:0.825179
# [3]	validation_0-rmse:0.817062
# [4]	validation_0-rmse:0.809383
# [5]	validation_0-rmse:0.802016
# [6]	validation_0-rmse:0.794916
# [7]	validation_0-rmse:0.788217
# [8]	validation_0-rmse:0.781780
# [9]	validation_0-rmse:0.775596
# [10]	validation_0-rmse:0.769533
# [11]	validation_0-rmse:0.763747
# [12]	validation_0-rmse:0.758275
# [13]	validation_0-rmse:0.753265
# [14]	validation_0-rmse:0.748449
# [15]	validation_0-rmse:0.743731
# [16]	validation_0-rmse:0.739360
# [17]	validation_0-rmse:0.735325
# [18]	validation_0-rmse:0.731446
# [19]	validation_0-rmse:0.727743
# [20]	validation_0-rmse:0.724130
# [21]	validation_0-rmse:0.720623
# [22]	validation_0-rmse:0.717322
# [23]	validation_0-rmse:0.714294
# [24]	validation_0-rmse:0.711129
# [25]	validation_0-rmse:0.708155
# [26]	validation_0-rmse:0.705598
# [27]	validation_0-rmse:0.702771
# [28]	validation_0-rmse:0.700235
# [29]	validation_0-rmse:0.697850
# [30]	validation_0-rmse:0.695693
# [31]	validation_0-rmse:0.693498
# [32]	validation_0-rmse:0.691451
# [33]	validation_0-rmse:0.689480
# [34]	validation_0-rmse:0.687536
# [35]	validation_0-rmse:0.685607
# [36]	validation_0-rmse:0.684019
# [37]	validation_0-rmse:0.682503
# [38]	validation_0-rmse:0.680768
# [39]	validation_0-rmse:0.679202
# [40]	validation_0-rmse:0.677787
# [41]	validation_0-rmse:0.676401
# [42]	validation_0-rmse:0.675184
# [43]	validation_0-rmse:0.673825
# [44]	validation_0-rmse:0.672560
# [45]	validation_0-rmse:0.671357
# [46]	validation_0-rmse:0.670413
# [47]	validation_0-rmse:0.669498
# [48]	validation_0-rmse:0.668386
# [49]	validation_0-rmse:0.667510
# [50]	validation_0-rmse:0.666590
# [51]	validation_0-rmse:0.665444
# [52]	validation_0-rmse:0.664639
# [53]	validation_0-rmse:0.663621
# [54]	validation_0-rmse:0.662834
# [55]	validation_0-rmse:0.662236
# [56]	validation_0-rmse:0.661516
# [57]	validation_0-rmse:0.660813
# [58]	validation_0-rmse:0.660210
# [59]	validation_0-rmse:0.659587
# [60]	validation_0-rmse:0.658908
# [61]	validation_0-rmse:0.658260
# [62]	validation_0-rmse:0.657673
# [63]	validation_0-rmse:0.657034
# [64]	validation_0-rmse:0.656401
# [65]	validation_0-rmse:0.655743
# [66]	validation_0-rmse:0.655161
# [67]	validation_0-rmse:0.654737
# [68]	validation_0-rmse:0.654293
# [69]	validation_0-rmse:0.653770
# [70]	validation_0-rmse:0.653245
# [71]	validation_0-rmse:0.652749
# [72]	validation_0-rmse:0.652286
# [73]	validation_0-rmse:0.651854
# [74]	validation_0-rmse:0.651459
# [75]	validation_0-rmse:0.651043
# [76]	validation_0-rmse:0.650688
# [77]	validation_0-rmse:0.650244
# [78]	validation_0-rmse:0.649824
# [79]	validation_0-rmse:0.649459
# [80]	validation_0-rmse:0.649078
# [81]	validation_0-rmse:0.648817
# [82]	validation_0-rmse:0.648544
# [83]	validation_0-rmse:0.648274
# [84]	validation_0-rmse:0.647987
# [85]	validation_0-rmse:0.647623
# [86]	validation_0-rmse:0.647235
# [87]	validation_0-rmse:0.646972
# [88]	validation_0-rmse:0.646766
# [89]	validation_0-rmse:0.646508
# [90]	validation_0-rmse:0.646213
# [91]	validation_0-rmse:0.646005
# [92]	validation_0-rmse:0.645746
# [93]	validation_0-rmse:0.645470
# [94]	validation_0-rmse:0.645204
# [95]	validation_0-rmse:0.644979
# [96]	validation_0-rmse:0.644696
# [97]	validation_0-rmse:0.644472
# [98]	validation_0-rmse:0.644263
# [99]	validation_0-rmse:0.644122
# [100]	validation_0-rmse:0.644016
# [101]	validation_0-rmse:0.643854
# [102]	validation_0-rmse:0.643675
# [103]	validation_0-rmse:0.643479
# [104]	validation_0-rmse:0.643190
# [105]	validation_0-rmse:0.643038
# [106]	validation_0-rmse:0.642773
# [107]	validation_0-rmse:0.642692
# [108]	validation_0-rmse:0.642481
# [109]	validation_0-rmse:0.642275
# [110]	validation_0-rmse:0.642186
# [111]	validation_0-rmse:0.641933
# [112]	validation_0-rmse:0.641858
# [113]	validation_0-rmse:0.641810
# [114]	validation_0-rmse:0.641626
# [115]	validation_0-rmse:0.641573
# [116]	validation_0-rmse:0.641406
# [117]	validation_0-rmse:0.641279
# [118]	validation_0-rmse:0.641251
# [119]	validation_0-rmse:0.641117
# [120]	validation_0-rmse:0.640971
# [121]	validation_0-rmse:0.640794
# [122]	validation_0-rmse:0.640716
# [123]	validation_0-rmse:0.640610
# [124]	validation_0-rmse:0.640589
# [125]	validation_0-rmse:0.640394
# [126]	validation_0-rmse:0.640226
# [127]	validation_0-rmse:0.640120
# [128]	validation_0-rmse:0.639942
# [129]	validation_0-rmse:0.639827
# [130]	validation_0-rmse:0.639691
# [131]	validation_0-rmse:0.639582
# [132]	validation_0-rmse:0.639426
# [133]	validation_0-rmse:0.639206
# [134]	validation_0-rmse:0.639112
# [135]	validation_0-rmse:0.639044
# [136]	validation_0-rmse:0.638906
# [137]	validation_0-rmse:0.638858
# [138]	validation_0-rmse:0.638826
# [139]	validation_0-rmse:0.638695
# [140]	validation_0-rmse:0.638639
# [141]	validation_0-rmse:0.638545
# [142]	validation_0-rmse:0.638485
# [143]	validation_0-rmse:0.638376
# [144]	validation_0-rmse:0.638395
# [145]	validation_0-rmse:0.638293
# [146]	validation_0-rmse:0.638177
# [147]	validation_0-rmse:0.638085
# [148]	validation_0-rmse:0.638051
# [149]	validation_0-rmse:0.637966
# [150]	validation_0-rmse:0.637959
# [151]	validation_0-rmse:0.637964
# [152]	validation_0-rmse:0.637834
# [153]	validation_0-rmse:0.637797
# [154]	validation_0-rmse:0.637766
# [155]	validation_0-rmse:0.637671
# [156]	validation_0-rmse:0.637637
# [157]	validation_0-rmse:0.637581
# [158]	validation_0-rmse:0.637469
# [159]	validation_0-rmse:0.637405
# [160]	validation_0-rmse:0.637361
# [161]	validation_0-rmse:0.637346
# [162]	validation_0-rmse:0.637261
# [163]	validation_0-rmse:0.637139
# [164]	validation_0-rmse:0.637050
# [165]	validation_0-rmse:0.636973
# [166]	validation_0-rmse:0.637007
# [167]	validation_0-rmse:0.636941
# [168]	validation_0-rmse:0.636862
# [169]	validation_0-rmse:0.636777
# [170]	validation_0-rmse:0.636701
# [171]	validation_0-rmse:0.636599
# [172]	validation_0-rmse:0.636564
# [173]	validation_0-rmse:0.636497
# [174]	validation_0-rmse:0.636396
# [175]	validation_0-rmse:0.636327
# [176]	validation_0-rmse:0.636316
# [177]	validation_0-rmse:0.636201
# [178]	validation_0-rmse:0.636128
# [179]	validation_0-rmse:0.636146
# [180]	validation_0-rmse:0.636139
# [181]	validation_0-rmse:0.636116
# [182]	validation_0-rmse:0.636041
# [183]	validation_0-rmse:0.636048
# [184]	validation_0-rmse:0.635982
# [185]	validation_0-rmse:0.635947
# [186]	validation_0-rmse:0.635898
# [187]	validation_0-rmse:0.635840
# [188]	validation_0-rmse:0.635789
# [189]	validation_0-rmse:0.635719
# [190]	validation_0-rmse:0.635697
# [191]	validation_0-rmse:0.635721
# [192]	validation_0-rmse:0.635698
# [193]	validation_0-rmse:0.635621
# [194]	validation_0-rmse:0.635569
# [195]	validation_0-rmse:0.635522
# [196]	validation_0-rmse:0.635494
# [197]	validation_0-rmse:0.635509
# [198]	validation_0-rmse:0.635512
# [199]	validation_0-rmse:0.635420
# [200]	validation_0-rmse:0.635401
# [201]	validation_0-rmse:0.635323
# [202]	validation_0-rmse:0.635291
# [203]	validation_0-rmse:0.635253
# [204]	validation_0-rmse:0.635192
# [205]	validation_0-rmse:0.635126
# [206]	validation_0-rmse:0.635141
# [207]	validation_0-rmse:0.635159
# [208]	validation_0-rmse:0.635109
# [209]	validation_0-rmse:0.635042
# [210]	validation_0-rmse:0.635005
# [211]	validation_0-rmse:0.634983
# [212]	validation_0-rmse:0.634970
# [213]	validation_0-rmse:0.634991
# [214]	validation_0-rmse:0.634933
# [215]	validation_0-rmse:0.634865
# [216]	validation_0-rmse:0.634827
# [217]	validation_0-rmse:0.634833
# [218]	validation_0-rmse:0.634870
# [219]	validation_0-rmse:0.634798
# [220]	validation_0-rmse:0.634750
# [221]	validation_0-rmse:0.634737
# [222]	validation_0-rmse:0.634666
# [223]	validation_0-rmse:0.634623
# [224]	validation_0-rmse:0.634628
# [225]	validation_0-rmse:0.634604
# [226]	validation_0-rmse:0.634446
# [227]	validation_0-rmse:0.634392
# [228]	validation_0-rmse:0.634380
# [229]	validation_0-rmse:0.634363
# [230]	validation_0-rmse:0.634286
# [231]	validation_0-rmse:0.634251
# [232]	validation_0-rmse:0.634266
# [233]	validation_0-rmse:0.634222
# [234]	validation_0-rmse:0.634184
# [235]	validation_0-rmse:0.634196
# [236]	validation_0-rmse:0.634167
# [237]	validation_0-rmse:0.634132
# [238]	validation_0-rmse:0.634092
# [239]	validation_0-rmse:0.634069
# [240]	validation_0-rmse:0.633996
# [241]	validation_0-rmse:0.633991
# [242]	validation_0-rmse:0.633977
# [243]	validation_0-rmse:0.633959
# [244]	validation_0-rmse:0.633974
# [245]	validation_0-rmse:0.633941
# [246]	validation_0-rmse:0.633898
# [247]	validation_0-rmse:0.633890
# [248]	validation_0-rmse:0.633881
# [249]	validation_0-rmse:0.633881
# [250]	validation_0-rmse:0.633850
# [251]	validation_0-rmse:0.633851
# [252]	validation_0-rmse:0.633829
# [253]	validation_0-rmse:0.633827
# [254]	validation_0-rmse:0.633825
# [255]	validation_0-rmse:0.633758
# [256]	validation_0-rmse:0.633744
# [257]	validation_0-rmse:0.633707
# [258]	validation_0-rmse:0.633702
# [259]	validation_0-rmse:0.633640
# [260]	validation_0-rmse:0.633656
# [261]	validation_0-rmse:0.633620
# [262]	validation_0-rmse:0.633611
# [263]	validation_0-rmse:0.633596
# [264]	validation_0-rmse:0.633553
# [265]	validation_0-rmse:0.633524
# [266]	validation_0-rmse:0.633539
# [267]	validation_0-rmse:0.633533
# [268]	validation_0-rmse:0.633520
# [269]	validation_0-rmse:0.633519
# [270]	validation_0-rmse:0.633489
# [271]	validation_0-rmse:0.633484
# [272]	validation_0-rmse:0.633395
# [273]	validation_0-rmse:0.633365
# [274]	validation_0-rmse:0.633388
# [275]	validation_0-rmse:0.633302
# [276]	validation_0-rmse:0.633298
# [277]	validation_0-rmse:0.633258
# [278]	validation_0-rmse:0.633210
# [279]	validation_0-rmse:0.633182
# [280]	validation_0-rmse:0.633171
# [281]	validation_0-rmse:0.633147
# [282]	validation_0-rmse:0.633097
# [283]	validation_0-rmse:0.633088
# [284]	validation_0-rmse:0.633052
# [285]	validation_0-rmse:0.633075
# [286]	validation_0-rmse:0.633051
# [287]	validation_0-rmse:0.633022
# [288]	validation_0-rmse:0.633042
# [289]	validation_0-rmse:0.632993
# [290]	validation_0-rmse:0.632950
# [291]	validation_0-rmse:0.632866
# [292]	validation_0-rmse:0.632850
# [293]	validation_0-rmse:0.632878
# [294]	validation_0-rmse:0.632839
# [295]	validation_0-rmse:0.632821
# [296]	validation_0-rmse:0.632807
# [297]	validation_0-rmse:0.632871
# [298]	validation_0-rmse:0.632892
# [299]	validation_0-rmse:0.632899
# [300]	validation_0-rmse:0.632883
# [301]	validation_0-rmse:0.632873
# [302]	validation_0-rmse:0.632828
# [303]	validation_0-rmse:0.632833
# [304]	validation_0-rmse:0.632813
# [305]	validation_0-rmse:0.632811
# [306]	validation_0-rmse:0.632772
# [307]	validation_0-rmse:0.632703
# [308]	validation_0-rmse:0.632702
# [309]	validation_0-rmse:0.632637
# [310]	validation_0-rmse:0.632563
# [311]	validation_0-rmse:0.632548
# [312]	validation_0-rmse:0.632505
# [313]	validation_0-rmse:0.632446
# [314]	validation_0-rmse:0.632454
# [315]	validation_0-rmse:0.632451
# [316]	validation_0-rmse:0.632430
# [317]	validation_0-rmse:0.632440
# [318]	validation_0-rmse:0.632371
# [319]	validation_0-rmse:0.632406
# [320]	validation_0-rmse:0.632375
# [321]	validation_0-rmse:0.632388
# [322]	validation_0-rmse:0.632363
# [323]	validation_0-rmse:0.632357
# [324]	validation_0-rmse:0.632345
# [325]	validation_0-rmse:0.632351
# [326]	validation_0-rmse:0.632318
# [327]	validation_0-rmse:0.632311
# [328]	validation_0-rmse:0.632329
# [329]	validation_0-rmse:0.632337
# [330]	validation_0-rmse:0.632365
# [331]	validation_0-rmse:0.632353
# [332]	validation_0-rmse:0.632323
# [333]	validation_0-rmse:0.632309
# [334]	validation_0-rmse:0.632316
# [335]	validation_0-rmse:0.632300
# [336]	validation_0-rmse:0.632266
# [337]	validation_0-rmse:0.632200
# [338]	validation_0-rmse:0.632170
# [339]	validation_0-rmse:0.632139
# [340]	validation_0-rmse:0.632137
# [341]	validation_0-rmse:0.632103
# [342]	validation_0-rmse:0.632106
# [343]	validation_0-rmse:0.632106
# [344]	validation_0-rmse:0.632096
# [345]	validation_0-rmse:0.632060
# [346]	validation_0-rmse:0.632061
# [347]	validation_0-rmse:0.632092
# [348]	validation_0-rmse:0.632064
# [349]	validation_0-rmse:0.632077
# [350]	validation_0-rmse:0.632054
# [351]	validation_0-rmse:0.632008
# [352]	validation_0-rmse:0.631944
# [353]	validation_0-rmse:0.631921
# [354]	validation_0-rmse:0.631929
# [355]	validation_0-rmse:0.631925
# [356]	validation_0-rmse:0.631921
# [357]	validation_0-rmse:0.631881
# [358]	validation_0-rmse:0.631899
# [359]	validation_0-rmse:0.631926
# [360]	validation_0-rmse:0.631915
# [361]	validation_0-rmse:0.631857
# [362]	validation_0-rmse:0.631847
# [363]	validation_0-rmse:0.631831
# [364]	validation_0-rmse:0.631829
# [365]	validation_0-rmse:0.631814
# [366]	validation_0-rmse:0.631810
# [367]	validation_0-rmse:0.631792
# [368]	validation_0-rmse:0.631812
# [369]	validation_0-rmse:0.631789
# [370]	validation_0-rmse:0.631742
# [371]	validation_0-rmse:0.631715
# [372]	validation_0-rmse:0.631666
# [373]	validation_0-rmse:0.631671
# [374]	validation_0-rmse:0.631679
# [375]	validation_0-rmse:0.631681
# [376]	validation_0-rmse:0.631658
# [377]	validation_0-rmse:0.631663
# [378]	validation_0-rmse:0.631675
# [379]	validation_0-rmse:0.631638
# [380]	validation_0-rmse:0.631620
# [381]	validation_0-rmse:0.631613
# [382]	validation_0-rmse:0.631604
# [383]	validation_0-rmse:0.631604
# [384]	validation_0-rmse:0.631601
# [385]	validation_0-rmse:0.631603
# [386]	validation_0-rmse:0.631600
# [387]	validation_0-rmse:0.631560
# [388]	validation_0-rmse:0.631556
# [389]	validation_0-rmse:0.631555
# [390]	validation_0-rmse:0.631531
# [391]	validation_0-rmse:0.631529
# [392]	validation_0-rmse:0.631530
# [393]	validation_0-rmse:0.631520
# [394]	validation_0-rmse:0.631507
# [395]	validation_0-rmse:0.631496
# [396]	validation_0-rmse:0.631474
# [397]	validation_0-rmse:0.631433
# [398]	validation_0-rmse:0.631418
# [399]	validation_0-rmse:0.631362
# [400]	validation_0-rmse:0.631352
# [401]	validation_0-rmse:0.631349
# [402]	validation_0-rmse:0.631333
# [403]	validation_0-rmse:0.631307
# [404]	validation_0-rmse:0.631325
# [405]	validation_0-rmse:0.631260
# [406]	validation_0-rmse:0.631251
# [407]	validation_0-rmse:0.631274
# [408]	validation_0-rmse:0.631254
# [409]	validation_0-rmse:0.631243
# [410]	validation_0-rmse:0.631224
# [411]	validation_0-rmse:0.631224
# [412]	validation_0-rmse:0.631231
# [413]	validation_0-rmse:0.631228
# [414]	validation_0-rmse:0.631220
# [415]	validation_0-rmse:0.631200
# [416]	validation_0-rmse:0.631209
# [417]	validation_0-rmse:0.631214
# [418]	validation_0-rmse:0.631222
# [419]	validation_0-rmse:0.631225
# [420]	validation_0-rmse:0.631191
# [421]	validation_0-rmse:0.631172
# [422]	validation_0-rmse:0.631129
# [423]	validation_0-rmse:0.631103
# [424]	validation_0-rmse:0.631116
# [425]	validation_0-rmse:0.631106
# [426]	validation_0-rmse:0.631101
# [427]	validation_0-rmse:0.631088
# [428]	validation_0-rmse:0.631059
# [429]	validation_0-rmse:0.631045
# [430]	validation_0-rmse:0.631028
# [431]	validation_0-rmse:0.631030
# [432]	validation_0-rmse:0.631002
# [433]	validation_0-rmse:0.631016
# [434]	validation_0-rmse:0.631009
# [435]	validation_0-rmse:0.630984
# [436]	validation_0-rmse:0.630960
# [437]	validation_0-rmse:0.630949
# [438]	validation_0-rmse:0.630906
# [439]	validation_0-rmse:0.630899
# [440]	validation_0-rmse:0.630870
# [441]	validation_0-rmse:0.630834
# [442]	validation_0-rmse:0.630804
# [443]	validation_0-rmse:0.630786
# [444]	validation_0-rmse:0.630764
# [445]	validation_0-rmse:0.630741
# [446]	validation_0-rmse:0.630744
# [447]	validation_0-rmse:0.630732
# [448]	validation_0-rmse:0.630738
# [449]	validation_0-rmse:0.630740
# [450]	validation_0-rmse:0.630740
# [451]	validation_0-rmse:0.630726
# [452]	validation_0-rmse:0.630729
# [453]	validation_0-rmse:0.630756
# [454]	validation_0-rmse:0.630722
# [455]	validation_0-rmse:0.630687
# [456]	validation_0-rmse:0.630648
# [457]	validation_0-rmse:0.630629
# [458]	validation_0-rmse:0.630629
# [459]	validation_0-rmse:0.630626
# [460]	validation_0-rmse:0.630599
# [461]	validation_0-rmse:0.630597
# [462]	validation_0-rmse:0.630602
# [463]	validation_0-rmse:0.630553
# [464]	validation_0-rmse:0.630544
# [465]	validation_0-rmse:0.630538
# [466]	validation_0-rmse:0.630507
# [467]	validation_0-rmse:0.630484
# [468]	validation_0-rmse:0.630481
# [469]	validation_0-rmse:0.630465
# [470]	validation_0-rmse:0.630452
# [471]	validation_0-rmse:0.630422
# [472]	validation_0-rmse:0.630425
# [473]	validation_0-rmse:0.630411
# [474]	validation_0-rmse:0.630401
# [475]	validation_0-rmse:0.630379
# [476]	validation_0-rmse:0.630394
# [477]	validation_0-rmse:0.630366
# [478]	validation_0-rmse:0.630358
# [479]	validation_0-rmse:0.630337
# [480]	validation_0-rmse:0.630307
# [481]	validation_0-rmse:0.630288
# [482]	validation_0-rmse:0.630296
# [483]	validation_0-rmse:0.630282
# [484]	validation_0-rmse:0.630278
# [485]	validation_0-rmse:0.630290
# [486]	validation_0-rmse:0.630252
# [487]	validation_0-rmse:0.630256
# [488]	validation_0-rmse:0.630217
# [489]	validation_0-rmse:0.630205
# [490]	validation_0-rmse:0.630212
# [491]	validation_0-rmse:0.630205
# [492]	validation_0-rmse:0.630172
# [493]	validation_0-rmse:0.630137
# [494]	validation_0-rmse:0.630135
# [495]	validation_0-rmse:0.630158
# [496]	validation_0-rmse:0.630169
# [497]	validation_0-rmse:0.630169
# [498]	validation_0-rmse:0.630176
# [499]	validation_0-rmse:0.630172
# [500]	validation_0-rmse:0.630178
# [501]	validation_0-rmse:0.630157
# [502]	validation_0-rmse:0.630141
# [503]	validation_0-rmse:0.630126
# [504]	validation_0-rmse:0.630152
# [505]	validation_0-rmse:0.630146
# [506]	validation_0-rmse:0.630148
# [507]	validation_0-rmse:0.630162
# [508]	validation_0-rmse:0.630147
# [509]	validation_0-rmse:0.630120
# [510]	validation_0-rmse:0.630105
# [511]	validation_0-rmse:0.630064
# [512]	validation_0-rmse:0.630031
# [513]	validation_0-rmse:0.629995
# [514]	validation_0-rmse:0.629977
# [515]	validation_0-rmse:0.629992
# [516]	validation_0-rmse:0.629979
# [517]	validation_0-rmse:0.630014
# [518]	validation_0-rmse:0.630019
# [519]	validation_0-rmse:0.630031
# [520]	validation_0-rmse:0.630013
# [521]	validation_0-rmse:0.630012
# [522]	validation_0-rmse:0.630019
# [523]	validation_0-rmse:0.630010
# [524]	validation_0-rmse:0.630015
# [525]	validation_0-rmse:0.630004
# [526]	validation_0-rmse:0.630005
# [527]	validation_0-rmse:0.629993
# [528]	validation_0-rmse:0.629986
# [529]	validation_0-rmse:0.630000
# [530]	validation_0-rmse:0.629998
# [531]	validation_0-rmse:0.629989
# [532]	validation_0-rmse:0.630001
# [533]	validation_0-rmse:0.630005
# [534]	validation_0-rmse:0.630027
# [535]	validation_0-rmse:0.630012
# [536]	validation_0-rmse:0.630018
# [537]	validation_0-rmse:0.630011
# [538]	validation_0-rmse:0.629982
# [539]	validation_0-rmse:0.629959
# [540]	validation_0-rmse:0.629977
# [541]	validation_0-rmse:0.629985
# [542]	validation_0-rmse:0.629973
# [543]	validation_0-rmse:0.629992
# [544]	validation_0-rmse:0.629994
# [545]	validation_0-rmse:0.629977
# [546]	validation_0-rmse:0.629974
# [547]	validation_0-rmse:0.629979
# [548]	validation_0-rmse:0.629934
# [549]	validation_0-rmse:0.629911
# [550]	validation_0-rmse:0.629904
# [551]	validation_0-rmse:0.629868
# [552]	validation_0-rmse:0.629867
# [553]	validation_0-rmse:0.629856
# [554]	validation_0-rmse:0.629854
# [555]	validation_0-rmse:0.629856
# [556]	validation_0-rmse:0.629834
# [557]	validation_0-rmse:0.629844
# [558]	validation_0-rmse:0.629840
# [559]	validation_0-rmse:0.629824
# [560]	validation_0-rmse:0.629820
# [561]	validation_0-rmse:0.629810
# [562]	validation_0-rmse:0.629806
# [563]	validation_0-rmse:0.629796
# [564]	validation_0-rmse:0.629795
# [565]	validation_0-rmse:0.629820
# [566]	validation_0-rmse:0.629807
# [567]	validation_0-rmse:0.629789
# [568]	validation_0-rmse:0.629796
# [569]	validation_0-rmse:0.629782
# [570]	validation_0-rmse:0.629774
# [571]	validation_0-rmse:0.629754
# [572]	validation_0-rmse:0.629724
# [573]	validation_0-rmse:0.629722
# [574]	validation_0-rmse:0.629723
# [575]	validation_0-rmse:0.629694
# [576]	validation_0-rmse:0.629690
# [577]	validation_0-rmse:0.629662
# [578]	validation_0-rmse:0.629668
# [579]	validation_0-rmse:0.629643
# [580]	validation_0-rmse:0.629630
# [581]	validation_0-rmse:0.629603
# [582]	validation_0-rmse:0.629593
# [583]	validation_0-rmse:0.629594
# [584]	validation_0-rmse:0.629591
# [585]	validation_0-rmse:0.629581
# [586]	validation_0-rmse:0.629583
# [587]	validation_0-rmse:0.629572
# [588]	validation_0-rmse:0.629581
# [589]	validation_0-rmse:0.629557
# [590]	validation_0-rmse:0.629545
# [591]	validation_0-rmse:0.629539
# [592]	validation_0-rmse:0.629510
# [593]	validation_0-rmse:0.629513
# [594]	validation_0-rmse:0.629495
# [595]	validation_0-rmse:0.629518
# [596]	validation_0-rmse:0.629508
# [597]	validation_0-rmse:0.629466
# [598]	validation_0-rmse:0.629460
# [599]	validation_0-rmse:0.629456
# [600]	validation_0-rmse:0.629440
# [601]	validation_0-rmse:0.629447
# [602]	validation_0-rmse:0.629467
# [603]	validation_0-rmse:0.629458
# [604]	validation_0-rmse:0.629473
# [605]	validation_0-rmse:0.629478
# [606]	validation_0-rmse:0.629504
# [607]	validation_0-rmse:0.629501
# [608]	validation_0-rmse:0.629497
# [609]	validation_0-rmse:0.629503
# [610]	validation_0-rmse:0.629492
# [611]	validation_0-rmse:0.629517
# [612]	validation_0-rmse:0.629491
# [613]	validation_0-rmse:0.629477
# [614]	validation_0-rmse:0.629476
# [615]	validation_0-rmse:0.629475
# [616]	validation_0-rmse:0.629442
# [617]	validation_0-rmse:0.629439
# [618]	validation_0-rmse:0.629427
# [619]	validation_0-rmse:0.629393
# [620]	validation_0-rmse:0.629389
# [621]	validation_0-rmse:0.629384
# [622]	validation_0-rmse:0.629385
# [623]	validation_0-rmse:0.629367
# [624]	validation_0-rmse:0.629353
# [625]	validation_0-rmse:0.629346
# [626]	validation_0-rmse:0.629325
# [627]	validation_0-rmse:0.629321
# [628]	validation_0-rmse:0.629321
# [629]	validation_0-rmse:0.629312
# [630]	validation_0-rmse:0.629303
# [631]	validation_0-rmse:0.629279
# [632]	validation_0-rmse:0.629290
# [633]	validation_0-rmse:0.629291
# [634]	validation_0-rmse:0.629279
# [635]	validation_0-rmse:0.629275
# [636]	validation_0-rmse:0.629258
# [637]	validation_0-rmse:0.629254
# [638]	validation_0-rmse:0.629253
# [639]	validation_0-rmse:0.629247
# [640]	validation_0-rmse:0.629257
# [641]	validation_0-rmse:0.629249
# [642]	validation_0-rmse:0.629260
# [643]	validation_0-rmse:0.629257
# [644]	validation_0-rmse:0.629268
# [645]	validation_0-rmse:0.629269
# [646]	validation_0-rmse:0.629287
# [647]	validation_0-rmse:0.629290
# [648]	validation_0-rmse:0.629291
# [649]	validation_0-rmse:0.629268
# [650]	validation_0-rmse:0.629276
# [651]	validation_0-rmse:0.629274
# [652]	validation_0-rmse:0.629273
# [653]	validation_0-rmse:0.629249
# [654]	validation_0-rmse:0.629248
# [655]	validation_0-rmse:0.629230
# [656]	validation_0-rmse:0.629227
# [657]	validation_0-rmse:0.629227
# [658]	validation_0-rmse:0.629252
# [659]	validation_0-rmse:0.629246
# [660]	validation_0-rmse:0.629227
# [661]	validation_0-rmse:0.629236
# [662]	validation_0-rmse:0.629226
# [663]	validation_0-rmse:0.629214
# [664]	validation_0-rmse:0.629198
# [665]	validation_0-rmse:0.629195
# [666]	validation_0-rmse:0.629197
# [667]	validation_0-rmse:0.629200
# [668]	validation_0-rmse:0.629197
# [669]	validation_0-rmse:0.629199
# [670]	validation_0-rmse:0.629206
# [671]	validation_0-rmse:0.629214
# [672]	validation_0-rmse:0.629197
# [673]	validation_0-rmse:0.629179
# [674]	validation_0-rmse:0.629155
# [675]	validation_0-rmse:0.629144
# [676]	validation_0-rmse:0.629132
# [677]	validation_0-rmse:0.629128
# [678]	validation_0-rmse:0.629127
# [679]	validation_0-rmse:0.629106
# [680]	validation_0-rmse:0.629087
# [681]	validation_0-rmse:0.629088
# [682]	validation_0-rmse:0.629084
# [683]	validation_0-rmse:0.629090
# [684]	validation_0-rmse:0.629077
# [685]	validation_0-rmse:0.629056
# [686]	validation_0-rmse:0.629069
# [687]	validation_0-rmse:0.629062
# [688]	validation_0-rmse:0.629065
# [689]	validation_0-rmse:0.629069
# [690]	validation_0-rmse:0.629087
# [691]	validation_0-rmse:0.629089
# [692]	validation_0-rmse:0.629083
# [693]	validation_0-rmse:0.629060
# [694]	validation_0-rmse:0.629046
# [695]	validation_0-rmse:0.629054
# [696]	validation_0-rmse:0.629038
# [697]	validation_0-rmse:0.629046
# [698]	validation_0-rmse:0.629044
# [699]	validation_0-rmse:0.629046
# [700]	validation_0-rmse:0.629046
# [701]	validation_0-rmse:0.629040
# [702]	validation_0-rmse:0.629034
# [703]	validation_0-rmse:0.629033
# [704]	validation_0-rmse:0.629033
# [705]	validation_0-rmse:0.629036
# [706]	validation_0-rmse:0.629036
# [707]	validation_0-rmse:0.629034
# [708]	validation_0-rmse:0.629037
# [709]	validation_0-rmse:0.629028
# [710]	validation_0-rmse:0.629007
# [711]	validation_0-rmse:0.629032
# [712]	validation_0-rmse:0.629028
# [713]	validation_0-rmse:0.629014
# [714]	validation_0-rmse:0.629015
# [715]	validation_0-rmse:0.629024
# [716]	validation_0-rmse:0.629009
# [717]	validation_0-rmse:0.629009
# [718]	validation_0-rmse:0.628999
# [719]	validation_0-rmse:0.629000
# [720]	validation_0-rmse:0.629000
# [721]	validation_0-rmse:0.629017
# [722]	validation_0-rmse:0.629017
# [723]	validation_0-rmse:0.629026
# [724]	validation_0-rmse:0.629021
# [725]	validation_0-rmse:0.629014
# [726]	validation_0-rmse:0.629016
# [727]	validation_0-rmse:0.629021
# [728]	validation_0-rmse:0.629016
# [729]	validation_0-rmse:0.628984
# [730]	validation_0-rmse:0.628979
# [731]	validation_0-rmse:0.628978
# [732]	validation_0-rmse:0.628957
# [733]	validation_0-rmse:0.628955
# [734]	validation_0-rmse:0.628962
# [735]	validation_0-rmse:0.628966
# [736]	validation_0-rmse:0.628962
# [737]	validation_0-rmse:0.628963
# [738]	validation_0-rmse:0.628965
# [739]	validation_0-rmse:0.628959
# [740]	validation_0-rmse:0.628971
# [741]	validation_0-rmse:0.628974
# [742]	validation_0-rmse:0.628986
# [743]	validation_0-rmse:0.628984
# [744]	validation_0-rmse:0.628974
# [745]	validation_0-rmse:0.628973
# [746]	validation_0-rmse:0.628983
# [747]	validation_0-rmse:0.628990
# [748]	validation_0-rmse:0.628987
# [749]	validation_0-rmse:0.628985
# [750]	validation_0-rmse:0.628987
# [751]	validation_0-rmse:0.628983
# [752]	validation_0-rmse:0.628973
# [753]	validation_0-rmse:0.628978
# [754]	validation_0-rmse:0.628968
# [755]	validation_0-rmse:0.628973
# [756]	validation_0-rmse:0.628969
# [757]	validation_0-rmse:0.628955
# [758]	validation_0-rmse:0.628921
# [759]	validation_0-rmse:0.628919
# [760]	validation_0-rmse:0.628924
# [761]	validation_0-rmse:0.628915
# [762]	validation_0-rmse:0.628927
# [763]	validation_0-rmse:0.628931
# [764]	validation_0-rmse:0.628936
# [765]	validation_0-rmse:0.628931
# [766]	validation_0-rmse:0.628931
# [767]	validation_0-rmse:0.628934
# [768]	validation_0-rmse:0.628933
# [769]	validation_0-rmse:0.628927
# [770]	validation_0-rmse:0.628918
# [771]	validation_0-rmse:0.628907
# [772]	validation_0-rmse:0.628893
# [773]	validation_0-rmse:0.628881
# [774]	validation_0-rmse:0.628882
# [775]	validation_0-rmse:0.628882
# [776]	validation_0-rmse:0.628910
# [777]	validation_0-rmse:0.628913
# [778]	validation_0-rmse:0.628917
# [779]	validation_0-rmse:0.628911
# [780]	validation_0-rmse:0.628906
# [781]	validation_0-rmse:0.628903
# [782]	validation_0-rmse:0.628902
# [783]	validation_0-rmse:0.628897
# [784]	validation_0-rmse:0.628887
# [785]	validation_0-rmse:0.628902
# [786]	validation_0-rmse:0.628913
# [787]	validation_0-rmse:0.628917
# [788]	validation_0-rmse:0.628922
# [789]	validation_0-rmse:0.628919
# [790]	validation_0-rmse:0.628926
# [791]	validation_0-rmse:0.628930
# [792]	validation_0-rmse:0.628936
# [793]	validation_0-rmse:0.628932
# [794]	validation_0-rmse:0.628927
# [795]	validation_0-rmse:0.628921
# [796]	validation_0-rmse:0.628907
# [797]	validation_0-rmse:0.628902
# [798]	validation_0-rmse:0.628891
# [799]	validation_0-rmse:0.628890
# (40000,)
# Completed!

# %%
# Score On Full Train Set
full_train_pred = clf.predict(X_train)
print(" -- Scores -- Full Train -- ")
print("Explained Variance Score: ", explained_variance_score(y_train, full_train_pred ))
print("Mean Absolute Error: ", mean_absolute_error(y_train, full_train_pred))
print("Mean Squared Error: ", mean_squared_error(y_train, full_train_pred))
print("Median Absolute Error: ", median_absolute_error(y_train, full_train_pred))
print("R2 Score: ", r2_score(y_train, full_train_pred))
print()
print()

# Score On Train Split
split_train_pred = clf.predict(X_fit)
print(" -- Scores -- Train Split -- ")
print("Explained Variance Score: ", explained_variance_score(y_fit, split_train_pred ))
print("Mean Absolute Error: ", mean_absolute_error(y_fit, split_train_pred))
print("Mean Squared Error: ", mean_squared_error(y_fit, split_train_pred))
print("Median Absolute Error: ", median_absolute_error(y_fit, split_train_pred))
print("R2 Score: ", r2_score(y_fit, split_train_pred))
print()
print()

# Score On Test Split
split_test_pred = clf.predict(X_eval)
print(" -- Scores -- Test Split -- ")
print("Explained Variance Score: ", explained_variance_score(y_eval, split_test_pred ))
print("Mean Absolute Error: ", mean_absolute_error(y_eval, split_test_pred))
print("Mean Squared Error: ", mean_squared_error(y_eval, split_test_pred))
print("Median Absolute Error: ", median_absolute_error(y_eval, split_test_pred))
print("R2 Score: ", r2_score(y_eval, split_test_pred))
print()
# Out:
#  -- Scores -- Full Train --
# ('Explained Variance Score: ', 0.12288845690577166)
# ('Mean Absolute Error: ', 1.1680984505049448)
# ('Mean Squared Error: ', 1.5809565444569298)
# ('Median Absolute Error: ', 1.3022047877311707)
# ('R2 Score: ', -1.2704238302970547)
# ()
# ()
#  -- Scores -- Train Split --
# ('Explained Variance Score: ', 0.97097319187479458)
# ('Mean Absolute Error: ', 0.09412809861606089)
# ('Mean Squared Error: ', 0.020090866678587407)
# ('Median Absolute Error: ', 0.060680128139495748)
# ('R2 Score: ', 0.97097304107734184)
# ()
# ()
#  -- Scores -- Test Split --
# ('Explained Variance Score: ', 0.44537335804096434)
# ('Mean Absolute Error: ', 0.40266924569205775)
# ('Mean Squared Error: ', 0.39550318099143866)
# ('Median Absolute Error: ', 0.23143208163852691)
# ('R2 Score: ', 0.44533661859079254)
# ()
