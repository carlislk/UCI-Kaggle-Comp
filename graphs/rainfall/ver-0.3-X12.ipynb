# %%
# Results

# Both Feature Sets
# [349]	validation_0-rmse:0.544184
# [160]	validation_0-rmse:0.536579

# Single Feature Set
# [160]	validation_0-rmse:0.561419

# 9th place  max_depth=20, n_estimators=161, learning_rate=0.03, nthread=4, subsample=0.95, colsample_bytree=0.85, seed=4242 )
#[160]	validation_0-rmse:0.118262

# %%
# Iris Data

from sklearn.cross_validation import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.pipeline import Pipeline
from sklearn.svm import OneClassSVM
import sklearn.linear_model as lm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import xgboost as xgb

# Data Files

# load data
df_train_1 = pd.read_csv('./data/kaggle.X1.train.txt', header=None)
df_train_2 = pd.read_csv('./data/kaggle.X2.train.txt', header=None)
df_train_Y = pd.read_csv('./data/kaggle.Y.train.txt', header=None)
df_test_1 = pd.read_csv('./data/kaggle.X1.test.txt', header=None)
df_test_2 = pd.read_csv('./data/kaggle.X2.test.txt', header=None)

# Combine Train Data 
df_train_X = pd.concat([df_train_1, df_train_2], axis=1)

# Combine Test Data 
df_test_X = pd.concat([df_test_1, df_test_2], axis=1)


# Create Numpy Arrays
X_train = df_train_X.values
y_train = df_train_Y.values
X_test = df_test_X.values

# Use Only X1
# X_train = df_train_1.values
# X_test = df_test_1.values

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
# Out:
# (60000, 532)
# (60000, 1)
# (40000, 532)

# %%
# Train Model

depth = 9
estimator = 1000
l_rate = 0.03
sub_sample = 0.9
col_sample = 0.85
seed_val = 4242
# n_round = 2
# verbose_val = 2
alpha_val = 0.8
min_child_val = 7
#lambda_val = 1.0

# classifier XBG Regression
clf = xgb.XGBRegressor(missing=np.nan, max_depth=depth, n_estimators=estimator, 
                       learning_rate=l_rate, nthread=12, subsample=sub_sample, colsample_bytree=col_sample, 
                       seed=seed_val, reg_alpha = alpha_val, min_child_weight=min_child_val)

X_fit, X_eval, y_fit, y_eval= train_test_split(X_train, y_train, test_size=0.2)

# fitting
# !! I Changed the fit paremeters to (X_fit, y_fit, )
clf.fit(X_fit, y_fit, early_stopping_rounds=20, eval_metric="rmse", eval_set=[(X_eval, y_eval)])

# predicting
y_pred= clf.predict(X_test)

print("Done!")
# Out:
# Will train until validation_0 error hasn't decreased in 20 rounds.
# [0]	validation_0-rmse:0.851245
# [1]	validation_0-rmse:0.840907
# [2]	validation_0-rmse:0.831007
# [3]	validation_0-rmse:0.821162
# [4]	validation_0-rmse:0.812004
# [5]	validation_0-rmse:0.803201
# [6]	validation_0-rmse:0.794634
# [7]	validation_0-rmse:0.786726
# [8]	validation_0-rmse:0.778659
# [9]	validation_0-rmse:0.771479
# [10]	validation_0-rmse:0.764326
# [11]	validation_0-rmse:0.757541
# [12]	validation_0-rmse:0.751120
# [13]	validation_0-rmse:0.744871
# [14]	validation_0-rmse:0.739028
# [15]	validation_0-rmse:0.733698
# [16]	validation_0-rmse:0.728159
# [17]	validation_0-rmse:0.722762
# [18]	validation_0-rmse:0.717746
# [19]	validation_0-rmse:0.712847
# [20]	validation_0-rmse:0.708274
# [21]	validation_0-rmse:0.703837
# [22]	validation_0-rmse:0.699718
# [23]	validation_0-rmse:0.695392
# [24]	validation_0-rmse:0.691878
# [433]	validation_0-rmse:0.591210
# [434]	validation_0-rmse:0.591184
# [435]	validation_0-rmse:0.591201
# [436]	validation_0-rmse:0.591181
# [437]	validation_0-rmse:0.591182
# [438]	validation_0-rmse:0.591209
# [439]	validation_0-rmse:0.591181
# [440]	validation_0-rmse:0.591198
# [441]	validation_0-rmse:0.591168
# [442]	validation_0-rmse:0.591138
# [443]	validation_0-rmse:0.591117
# [444]	validation_0-rmse:0.591108
# [445]	validation_0-rmse:0.591115
# [446]	validation_0-rmse:0.591097
# [447]	validation_0-rmse:0.591088
# [448]	validation_0-rmse:0.591056
# [449]	validation_0-rmse:0.590947
# [450]	validation_0-rmse:0.590946
# [451]	validation_0-rmse:0.590969
# [452]	validation_0-rmse:0.590985
# [453]	validation_0-rmse:0.590977
# [454]	validation_0-rmse:0.590969
# [455]	validation_0-rmse:0.590960
# [456]	validation_0-rmse:0.590935
# [457]	validation_0-rmse:0.590916
# [458]	validation_0-rmse:0.590904
# [459]	validation_0-rmse:0.590902
# [460]	validation_0-rmse:0.590912
# [461]	validation_0-rmse:0.590878
# [462]	validation_0-rmse:0.590811
# [463]	validation_0-rmse:0.590763
# [464]	validation_0-rmse:0.590748
# [465]	validation_0-rmse:0.590727
# [466]	validation_0-rmse:0.590720
# [467]	validation_0-rmse:0.590709
# [468]	validation_0-rmse:0.590701
# [469]	validation_0-rmse:0.590665
# [470]	validation_0-rmse:0.590646
# [471]	validation_0-rmse:0.590635
# [472]	validation_0-rmse:0.590634
# [473]	validation_0-rmse:0.590618
# [474]	validation_0-rmse:0.590645
# [475]	validation_0-rmse:0.590657
# [476]	validation_0-rmse:0.590666
# [477]	validation_0-rmse:0.590641
# [478]	validation_0-rmse:0.590640
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-133-4454940b12fb> in <module>()
#      22 # fitting
#      23 # !! I Changed the fit paremeters to (X_fit, y_fit, )
# ---> 24 clf.fit(X_fit, y_fit, early_stopping_rounds=20, eval_metric="rmse", eval_set=[(X_eval, y_eval)])
#      25
#      26 # predicting
#
# /usr/local/lib/python2.7/dist-packages/xgboost-0.4a30-py2.7.egg/xgboost/sklearn.pyc in fit(self, X, y, eval_set, eval_metric, early_stopping_rounds, verbose)
#     186                               early_stopping_rounds=early_stopping_rounds,
#     187                               evals_result=evals_result, feval=feval,
# --> 188                               verbose_eval=verbose)
#     189
#     190         if evals_result:
#
# /usr/local/lib/python2.7/dist-packages/xgboost-0.4a30-py2.7.egg/xgboost/training.pyc in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, learning_rates, xgb_model)
#     196                 else:
#     197                     bst.set_param({'eta': learning_rates(i, num_boost_round)})
# --> 198             bst.update(dtrain, i, obj)
#     199             nboost += 1
#     200             bst_eval_set = bst.eval_set(evals, i, feval)
#
# /usr/local/lib/python2.7/dist-packages/xgboost-0.4a30-py2.7.egg/xgboost/core.pyc in update(self, dtrain, iteration, fobj)
#     692
#     693         if fobj is None:
# --> 694             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, iteration, dtrain.handle))
#     695         else:
#     696             pred = self.predict(dtrain)
#
# KeyboardInterrupt:

# %%
# Score

from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import median_absolute_error
from sklearn.metrics import r2_score

# Print Parameters
print("Parameters")
print()
print("Depth: ", depth)
print("estimator: ", estimator)
print("l_rate: ", l_rate)
print("sub_sample: ", sub_sample)
print("col_sample: ", col_sample)
print("seed: ", seed_val)
print("Alpha: ", alpha_val)
#print("Lambda: ", lambda_val)
# print("Num Rounds: ", n_round)
# print("Verbose Val: ", verbose_val)
print()
print()


# Score On Full Train Set
full_train_pred = clf.predict(X_train)
print(" -- Scores -- Full Train -- ")
print("Explained Variance Score: ", explained_variance_score(y_train, full_train_pred ))
print("Mean Absolute Error: ", mean_absolute_error(y_train, full_train_pred))
print("Mean Squared Error: ", mean_squared_error(y_train, full_train_pred))
print("Median Absolute Error: ", median_absolute_error(y_train, full_train_pred))
print("R2 Score: ", r2_score(y_train, full_train_pred))
print()
print()

# Score On Train Split
split_train_pred = clf.predict(X_fit)
print(" -- Scores -- Train Split -- ")
print("Explained Variance Score: ", explained_variance_score(y_fit, split_train_pred ))
print("Mean Absolute Error: ", mean_absolute_error(y_fit, split_train_pred))
print("Mean Squared Error: ", mean_squared_error(y_fit, split_train_pred))
print("Median Absolute Error: ", median_absolute_error(y_fit, split_train_pred))
print("R2 Score: ", r2_score(y_fit, split_train_pred))
print()
print()

# Score On Test Split
split_test_pred = clf.predict(X_eval)
print(" -- Scores -- Test Split -- ")
print("Explained Variance Score: ", explained_variance_score(y_eval, split_test_pred ))
print("Mean Absolute Error: ", mean_absolute_error(y_eval, split_test_pred))
print("Mean Squared Error: ", mean_squared_error(y_eval, split_test_pred))
print("Median Absolute Error: ", median_absolute_error(y_eval, split_test_pred))
print("R2 Score: ", r2_score(y_eval, split_test_pred))
print()
# Out:
# Parameters
# ()
# ('Depth: ', 9)
# ('estimator: ', 10000)
# ('l_rate: ', 0.03)
# ('sub_sample: ', 0.9)
# ('col_sample: ', 0.8)
# ('seed: ', 4242)
# ('Alpha: ', 0.8)
# ()
# ()
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# <ipython-input-129-4ae2a540e90f> in <module>()
#      25
#      26 # Score On Full Train Set
# ---> 27 full_train_pred = clf.predict(X_train)
#      28 print(" -- Scores -- Full Train -- ")
#      29 print("Explained Variance Score: ", explained_variance_score(y_train, full_train_pred ))
#
# /usr/local/lib/python2.7/dist-packages/xgboost-0.4a30-py2.7.egg/xgboost/sklearn.pyc in predict(self, data, output_margin, ntree_limit)
#     202         # pylint: disable=missing-docstring,invalid-name
#     203         test_dmatrix = DMatrix(data, missing=self.missing)
# --> 204         return self.booster().predict(test_dmatrix,
#     205                                       output_margin=output_margin,
#     206                                       ntree_limit=ntree_limit)
#
# /usr/local/lib/python2.7/dist-packages/xgboost-0.4a30-py2.7.egg/xgboost/sklearn.pyc in booster(self)
#     107         """
#     108         if self._Booster is None:
# --> 109             raise XGBoostError('need to call fit beforehand')
#     110         return self._Booster
#     111
#
# XGBoostError: need to call fit beforehand

# %%
# Score on Test File From 9th Place Prediction

# %%
# Write To File
import csv

write_file = open('predictions_1.csv', 'w')
write_file.write('ID,Prediction\n')
for x,y in enumerate(y_pred):
    write_file.write('{},{} \n'.format(x+1, y))
    
                     
write_file.close()

print(y_pred.shape)

print('Completed!')
# Out:
# (40000,)
# Completed!
